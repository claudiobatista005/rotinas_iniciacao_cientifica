# %% [markdown]
# # Algoritmo - Localização Bilhetagem (incluindo terminais e outros)
# ### Autor: Antônio Claudio Dutra Batista
# ### Orientador: Francisco Moraes de Oliveria Neto
# ### Metodologia: Mesclagem por informações coincidentes e critério de tempo

# %% [markdown]
# # 1.0  Leitura das Bases

# %% [markdown]
# ## 1.1 leitura da base - Bilhetagem (Tratamento Inicial)

# %%
import pandas as pd 
# Arquivos são do mês de novembro de 2018.
# Definindo tipos de variaveis com tamanhos menores
tipos_specification = {'id': 'int32', 'linha': 'int32'}

# df's abaixo (leitura somente das colunas necessárias):
dia_01 = pd.read_csv('2018-11-01.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification, sep= ',')
dia_02 = pd.read_csv('2018-11-02.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_03 = pd.read_csv('2018-11-03.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_04 = pd.read_csv('2018-11-04.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_05 = pd.read_csv('2018-11-05.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification, sep= ',') 
dia_06 = pd.read_csv('2018-11-06.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_07 = pd.read_csv('2018-11-07.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_08 = pd.read_csv('2018-11-08.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification, sep= ',')
dia_09 = pd.read_csv('2018-11-09.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_10 = pd.read_csv('2018-11-10.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\3162197571.py:16: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   dia_10 = pd.read_csv('2018-11-10.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')

# %%
# Continuando...
dia_11 = pd.read_csv('2018-11-11.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_12 = pd.read_csv('2018-11-12.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_13 = pd.read_csv('2018-11-13.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_14 = pd.read_csv('2018-11-14.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_15 = pd.read_csv('2018-11-15.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_16 = pd.read_csv('2018-11-16.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_17 = pd.read_csv('2018-11-17.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_18 = pd.read_csv('2018-11-18.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_19 = pd.read_csv('2018-11-19.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification, sep= ',')
dia_20 = pd.read_csv('2018-11-20.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification, sep= ',')

# %%
# Continuando...
dia_21 = pd.read_csv('2018-11-21.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_22 = pd.read_csv('2018-11-22.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_23 = pd.read_csv('2018-11-23.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_24 = pd.read_csv('2018-11-24.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_25 = pd.read_csv('2018-11-25.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_26 = pd.read_csv('2018-11-26.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_27 = pd.read_csv('2018-11-27.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_28 = pd.read_csv('2018-11-28.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_29 = pd.read_csv('2018-11-29.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')
dia_30 = pd.read_csv('2018-11-30.csv', usecols=['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao','dia', 'momento'], dtype=tipos_specification,  sep= ',')

# %%
# Agrupando (10 dias)
dia_01_10 = pd.concat([dia_01, dia_02, dia_03, dia_04, dia_05, dia_06 ,dia_07, dia_08, dia_09, dia_10])

# %%
# Continuando...
dia_11_20 = pd.concat([dia_11, dia_12, dia_13, dia_14, dia_15,dia_16, dia_17, dia_18, dia_19, dia_20])

# %%
# Continuando...
dia_21_30 = pd.concat([dia_21, dia_22, dia_23, dia_24, dia_25, dia_26, dia_27, dia_28, dia_29, dia_30])

# %%
mes_tudo = pd.concat([dia_01_10, dia_11_20,dia_21_30])

# %%
# DELETANDO EXPLICITAMENTE VARAIVEIS COM DIAS 01-10
del dia_01
del dia_02
del dia_03
del dia_04
del dia_05
del dia_06
del dia_07
del dia_08
del dia_09
del dia_10

# %%
# DELETANDO EXPLICITAMENTE VARAIVEIS COM DIAS 11-20
del dia_11
del dia_12
del dia_13
del dia_14
del dia_15
del dia_16
del dia_17
del dia_18
del dia_19
del dia_20

# %%
# DELETANDO EXPLICITAMENTE VARAIVEIS COM DIAS 21-30
del dia_21
del dia_22
del dia_23
del dia_24
del dia_25
del dia_26
del dia_27
del dia_28
del dia_29
del dia_30

# %%
# DELETANDO EXPLICITAMENTE VARAIVEIS COM DIAS 1agrupados
del dia_01_10
del dia_11_20
del dia_21_30

# %%
# Caso necessite exportar arquivo da bilhetagem completa
# mes_tudo.to_csv("mes_tudo")

# %%
''' FORMATAÇÃO INICIAL '''
# Out:
# ' FORMATAÇÃO INICIAL '

# %%
# Momentos em ordem do df mes_c_R!
# mes_tudo.sort_values('momento', inplace = True) # Mostrando DF em ORDEM!

# %%
# Juntando colunas de interesse (dia, momento) em uma só:
mes_tudo["momento"] = mes_tudo['dia'].astype(str) + '-' + mes_tudo['momento'].astype(str)

# %%
# REMOVENDO COLUNAS DESNECESSÁRIAS!
mes_tudo.drop(['dia'], inplace= True, axis=1)

# %% [markdown]
# ### 1.1.1 Inspeção inicial

# %%
# Informações da base
mes_tudo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24919015 entries, 0 to 929957
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  object
#  4   tipo_cartao    object
#  5   momento        object
# dtypes: int32(2), object(4)
# memory usage: 1.1+ GB

# %%
# Dados nulos 
mes_tudo.isnull().sum()
# Out:
# id                   0
# linha                0
# nome_linha         906
# prefixo_carro    27239
# tipo_cartao          0
# momento              0
# dtype: int64

# %%
# Verificando linhas utilizadas 
nomes_linhas = mes_tudo['nome_linha']
nomes_linhas.unique()
# Out:
# array(['Luc. Cavalca./Papicu', 'Parangaba/Centro/Exp',
#        'Messejana/Parangaba ', 'MESSEJANA/RODOVIARIA',
#        'SIQUEIRA/PAPICU/WASH', 'EXPRESSO/SIQUEIRA/PA',
#        'Antonio Bezerra/Siqu', 'Messej/Pap/Camb', 'MESSEJANA/PAPICU/CAM',
#        'Siqueira/Messejana/P', 'Dom Luiz            ',
#        'Joquei/Bonsucesso   ', 'Grande Circular 1   ',
#        'Cj Tancredo Neves/No', 'Cidade Func/Sitio Sa',
#        'CIDADE DOS FUNCIONAR', 'Av. Antonio Sales/Di',
#        'Parangaba/Nautico   ', 'MESSEJANA/PAPICU/MAN',
#        'Siqueira/Papicu/Aero', 'HGF/PAPICU', 'Cidade Func/Cj Alvor',
#        'Montese/Parangaba   ', 'Dias Macedo/Cent    ',
#        'Ant. Bezerra/Mess/Pe', 'Alvorada / Messejana',
#        'PARQUE BETANIA/MESSE', 'DEFENSORIA/PAPICU/VI',
#        'Cidade Func/Papicu/C', 'Parangaba / Olivei  ',
#        'Grande Circular 2   ', 'Parangaba/Papicu    ', 'SIQ/PAP/WS.',
#        'Parangaba/Joao Pesso', 'Jardim Jatoba/Centro',
#        'MIGUEL ARRAIS/SIQUEI', 'Siqueira/Joao Pessoa',
#        'Jardim Jatoba/Siquei', 'Jardim Jatoba 2     ',
#        'Democrito Rocha     ', 'Genibau/Lagoa       ',
#        'Vila Manoel Satiro/C', 'Genibau/Centro      ',
#        'Pq.Pio XII/Ana Gonca', 'Canindezinho        ',
#        'Siqueira/Mucuripe/Ba', 'ARACAPE/PARANGABA 1',
#        'Cj Esperanca/Centro ', 'ceara/lagoa/aanjos',
#        'Cj Itaperi          ', 'Aguanambi 1         ',
#        'Corujao/Montese     ', 'ANTONIO BEZERRA/CENT',
#        'Cj Ceara/Centro/2a  ', 'Cj Ceara/Antonio Bez',
#        'Cj. Ceara /Aldeo    ', 'Parque Sao Vicente  ',
#        'Cj Esperanca/Paranga', 'Pq.Sao Jose/Osorio d',
#        'Granja Portugal/Lago', 'Joao  XXIII/Centro  ',
#        'Cj Ceara/Centro/3a E', 'Ant. Bez./Fco sa/Pap', 'AB/PAP/PIRA',
#        'Jovita Feitosa', 'Antonio Bezerra/Albe', 'Cj Pref. Jose Walter',
#        'Plan. Ayrton S/Exped', 'Joao XXIII/Lagoa    ',
#        'Arvoredo/Parangaba  ', 'Siqueira/Papicu/13 d',
#        'Papicu/Caca Pesca   ', 'Edson Queiroz/Papicu',
#        'Lagoa Redonda 1     ', 'Papicu/Cidade 2000  ',
#        'Papicu/Castelo Encan', 'Jd. Oliveiras/Centro',
#        'Papicu/Cj Alvorada  ', 'Parque Manibura/Borg',
#        'Castelo Encantado/Ce', 'MES/PAP / WS', 'Bezerra / S.Dumont',
#        'Parangaba/Mucuripe  ', 'Caca e Pesca/Servilu',
#        'MESSEJANA/SABIAGUABA', 'Corujao/Av. Paranjan',
#        'Cidade Func/Cofeco/L', 'Lagoa Redonda 2     ',
#        'Praia do Futuro/Caca', 'EXP/BEZ/SDUM', 'Corujao/Grande Circu',
#        'Lagoa Redonda/Abreul', 'Estacao/Pio Saraiva ',
#        'CUCA BARRA/PAPICU', 'Jardim Iracema      ',
#        'Cj Sao Cristovao    ', 'Cj Tamandare        ',
#        'Sitio Sao Joao/Centr', 'Pedras 1            ',
#        'Barroso/Jardim Viole', 'Pedras 2            ',
#        'Paupina             ', 'Cj Joao Paulo II    ',
#        'Parque Santa Rosa/Me', 'Vila do Mar/Centro',
#        'RODOLFO TEOFILO/JOSE', 'Corujao/Jd.Guanabara', 'FLORESTA/CENTRO',
#        'Cj Palmeiras/Perimet', 'Sitio Sao Joao/Parqu',
#        'Messejana/Centro/Br ', 'Itamaraty/Elizabeth ',
#        'Guajeru 2           ', 'PLANALTO COACU/MESSE',
#        'Parque Santa Maria/M', 'Alto Alegre/Messejan',
#        'Cj Palmeiras/Parque ', 'ANTONIO BEZERRA/LAGO',
#        'lagoa/aldeota/j.bast', 'Bela Vista/Humberto ',
#        'ANTONIO BEZERRA/PAPI', 'Antonio Bezerra/Mucu',
#        'Lagoa/Papicu/Via Exp', 'Parangaba/Papicu/Mon',
#        'Cj Ceara/Papicu/Mont', 'Pq.Dois Irmaos/Exped',
#        'Castelao/Visconde do', 'Cj Veneza Tropical/M',
#        'Parangaba/Parque Ver', 'Parangaba/Papicu/Aer',
#        'Passare/Messejana', 'Cj Sumare/Parangaba ',
#        'Aeroporto/Benfica/Ro', 'Passare / Parangaba',
#        'Vila Uniao          ', 'Aerolandia 1        ',
#        'Corujao/Parangaba/Pa', 'Corujao/Barroso/Jard',
#        'Varjota             ', 'Gereberaba/ Messejan',
#        'Sitio Corrego/Parang', 'Cj Jose Walter/Paran',
#        'LAGOA REDONDA/PAPICU', 'Campus do Pici/Unifo',
#        'Av. Borges de Melo 1', 'Jardim Castelao     ',
#        'Jardim Uniao/Paranga', 'Planalto Ayrton Senn',
#        'Dias Macedo/Parangab', 'Parangaba/Alto da Pa',
#        'Santa Tereza        ', 'PASSARE / CEN       ',
#        'Conjunto palmeiras/C', 'EXPRESSO / ANTONIO B',
#        'Circular 2          ', 'Antonio Bezerra/Unif',
#        'VILA DO MAR / ANTONI', 'Barroso Circular    ',
#        'Circular 1          ', 'Francisco Sa/Paranga',
#        'Alvaro Weyne/Centro ', 'Beira Rio           ',
#        'Antonio Bezerra/Alva', 'ALAMEDA DAS PALMEIRA',
#        'PADRE ANDRADE/ANTO  ', 'Aldeota             ',
#        'Papicu/Praia do Futu', 'Av. Borges de Melo 2',
#        'Corujao/Paupina/Lago', '680-JOSE WALTER / PA',
#        'VILA SANTO ANTONIO/R', 'Antonio Bezerra/Mess',
#        'Carlos Albuquerque  ', 'Guajeru I           ',
#        'Cj Curio            ', 'Av. 13 de Maio 1    ',
#        'Parque Americano    ', 'Corujao/Messejana/Ce',
#        'Cidade Nova/Parangab', 'SIQUEIRA/P.IRACEMA',
#        'LAGOA / ALBERT SABIN', 'Bezerra de Menezes/ ',
#        'PARQUE ST MARIA/ LIC', 'CONJ. PALMEIRAS/ HOS',
#        'PARQUEL/PARANGABA', 'Cidade Func/Papicu/J',
#        'Edson Queiroz/Centro', 'CIDADE JARDIM/PARANG',
#        'Cidade 2000/Centro  ', 'PAUPINA/PICI', 'Antonio Bezerra     ',
#        'Igreja Sao Raimundo ', 'AV LINEU MACHADO/SP2',
#        'Av. Lineu Machado', 'CIDADE 2000/ SARGENT',
#        'Messejana/Sabiaguaba', 'LAGOA REDONDA/ABREUL',
#        'Siqueira/Jose Bastos', 'Cj Ceara/4a Etapa   ',
#        'Messejana/Frei Ciril', 'Cj Esperanca/Siqueir',
#        'Av. 13 de Maio 2    ', 'Corujao/Cj Ceara    ',
#        'Parque Santana      ', 'Corujao/Cj Esperanca',
#        'JOSE WALTER/ CENTRO', 'CIDADE NOBRE/MESSEJA',
#        'GRANJA LISBOA/ GOIAB', 'CONJ. CEARA/ GRANJA ',
#        'Aguanambi 2         ', 'Antonio Bezerra/Naut',
#        'VILA VELHA/ CENTRO', 'BARRA DO CEARA/ CAIS',
#        'Bela Vista/Lagoa    ', 'Corujao/Cj Ceara/Pap',
#        'SANTOS DUMONT/ PERIM', 'Montese/Lagoa       ',
#        'Cj Ceara/Lagoa/F.Tav', 'Cj Ceara/Siqueira   ', 'ARACAPE/CENTRO',
#        'SANTA FE 02', 'Quintino Cunha/Anton', 'Cuca Barra/Parangaba',
#        'PQ. SAO JOAO / SIQUE', 'Cj Ceara/Granja Lisb',
#        'Corujao/Cj Ceara/Ald', 'Parque Universitario',
#        'Jd.Guanabara/N. A. 2', 'TERMINAL PARANGABA',
#        'Bela Vista/Viriato R', 'LAGOA/OPAIA', 'Jd.Guanabara/N. A. 1',
#        'Jardim Guanabara/Fra', 'Cj Nova Assuncao/Fra',
#        'Campus Univ./Pan Ame', 'Henrique Jorge      ',
#        'Av. Sargento Hermini', 'Corujao/Av. Bezerra ',
#        'Aracape/Parangaba   ', 'Parque Presidente Va',
#        'Itaoca/Jardim Americ', 'Modubim/Siqueira    ',
#        'CJ NOVO LAR/SIQUEIRA', 'Castelao/Parangaba  ',
#        'Planalto Granja Lisb', 'ANTONIO BEZERRA/PARA',
#        'Siqueira/Lagoa      ', 'SANTA MARIA/BAIRRO E', 'LINHA CENTRAL',
#        'Corujao/Edson Queiro', 'Parque Santa Cecilia', 'Conj. Tatu Munde',
#        'Parque Santa Rosa/Si', 'Parque Jerusalem    ',
#        'Bom Jardim/Centro', 'Siqueira/V.M.S./PARA',
#        'Jardim Fluminense   ', 'Bom Jardim 1        ',
#        'Bom Jardim 2        ', 'Parque Santa Maria/S',
#        'Joao Arruda         ', 'Vila Betania/Paranga',
#        'Vila Sto. Antonio/Ns', 'Corujao/Pedras', 'Antonio Bezerra / Pa',
#        'Cj Sao Bernardo     ', 'Meireles            ',
#        'Papicu/Serviluz/Varj', 'Olavo Oliveira/Vila ',
#        'VILA VELHA/RIOMAR KE', 'Av. Jose Bastos     ', 'TERM.ANT.BEZERRA',
#        'ARACAPE/SIQUEIRA ', 'NOVA ESPERANCA/SIQUE', 'TERMINAL PAPICU',
#        'CONJ. CEARA/CENTRO', 'CACA E PESCA/ CENTRO',
#        'CONJ. ALVORADA/ NORT', 'Caca e Pesca/Centro/',
#        'BARRA DO CEARA/ANTON', 'Parque Univ./Ant. Be',
#        'CJ CEARA/BOM JARDIM/', 'Cj Ceara/Bom Jardim ',
#        'Corujao/Bom Jardim  ', 'Siqueira/OP/Parangab',
#        'Autran Nunes        ', 'Intershoppings', 'LAGOA/RIOMAR/JOSE JA',
#        'Cj Ceara/1a Etapa', 'AEROPORTO/BEIRA MAR', 'SIT CURIO/MESS',
#        'Conj. Maria Tomasia/', 'Bairro de Fatima    ',
#        'Canindezinho/Urucutu', 'PARANGABA/UECE/LUCIA',
#        'Corujao/Praia do Fut', 'Dom Lustosa         ',
#        'TERMINAL MESSEJANA', 'Antonio Bezerra/Papi', 'EXP/A.BEZ/MES',
#        'TERMINAL SIQUEIRA', 'TERMINAL CEARA', 'TERMINAL LAGOA',
#        'Corujao/Jardim Irace', 'Corujao/Circular 1  ',
#        'Corujao/Cj Pref. Jos', 'CORUJAO/JOSE BASTOS/',
#        'Corujao/Av. Sargento', 'Corujao/Aeroporto/Be',
#        'JOSE WALTER/CIDADE J', 'CONJUNTO DONA YOLAND',
#        'Corujao/Jose Bastos/', 'Siqueira/Mucuripe   ',
#        'SIQUEIRA/PARQUE DA S', 'Papicu/Hospital Gera',
#        'PAPICU/PRAIA DO FUTU', 'SIQUEIRA/CEMITERIO B',
#        'VILA DO MAR/NAUTICO ', 'Conj. Ceara / Cemite',
#        'MONTESE/LAGOA/PARANG', 'PARANGABA/PAULO SARA',
#        'Vila do Mar/ Centro ', 'ANT. BEZERRA/PAULO S',
#        'SIQUEIRA/PAULO SARAS', 'CAMPOS DO PICI', 'MESSEJANA/PAULO SARA',
#        'PAPICU/PAULO SARASAT', 'Parangaba/Lagoa     ', nan,
#        'Siqueira/Centro/Expr', 'PARANGABA/NAUTICO II',
#        'EXPRESSO/PARANGABA/P', 'EXP/ANTB/PAR', 'CONJ. CEARA/PAULO SA',
#        'Expresso/Cj Ceara/Pa', 'VILA VELHA/NORTH SHO',
#        'AEROLANDIA/SP2    ', 'EXPRESSO/MESSEJANA/P', 'Castelao/Lagoa',
#        'PARANGABA - NORTH SH', 'SEUMA/ARENA CASTELAO',
#        'Siq/Mucuripe/Ba II', 'Anto Bezerra/Unif II',
#        'Parang/Papicu/Mon II', 'ESPECIAL', 'Castelao/Antonio Bez'],
#       dtype=object)

# %%
# Visualisando dados de identifcação dos veciulos nulos
veiclulos_nao_identificados = mes_tudo[mes_tudo['prefixo_carro'].isnull()]
df_nao_identificados =  veiclulos_nao_identificados['nome_linha'].value_counts()

# %%
df_nao_identificados
# Out:
# TERMINAL SIQUEIRA       21995
# GRANJA LISBOA/ GOIAB     5244
# Name: nome_linha, dtype: int64

# %%
''' Ou seja, duas linhas tiveram dados nulos de identificação dos veiculos'''
# Out:
# ' Ou seja, duas linhas tiveram dados nulos de identificação dos veiculos'

# %%
# Visualisando dados de identifcação dos nomes das linhas nulos
nome_linha_nao_identificados = mes_tudo[mes_tudo['nome_linha'].isnull()]

# %%
nome_linha_nao_identificados
# Out:
#              id  linha nome_linha prefixo_carro      tipo_cartao  \
# 2628    5559333    811        NaN       30103.0        Estudante
# 2629    5853453    811        NaN       30103.0  Vale transporte
# 2630    2612929    811        NaN       30103.0        Estudante
# 2631    2787412    811        NaN       30103.0        Estudante
# 2632    2544623    811        NaN       30103.0        Estudante
# ...         ...    ...        ...           ...              ...
# 371391  5584087    811        NaN       30128.0        Estudante
# 371392  2551369    811        NaN       30128.0        Estudante
# 371393  2914181    811        NaN       30128.0        Estudante
# 382051  4408847    811        NaN       30323.0  Vale transporte
# 382052   533979    811        NaN       30323.0        Estudante
#
#                     momento
# 2628    2018-11-04-18:51:23
# 2629    2018-11-04-18:57:58
# 2630    2018-11-04-18:11:58
# 2631    2018-11-04-18:13:11
# 2632    2018-11-04-18:14:19
# ...                     ...
# 371391  2018-11-11-17:13:48
# 371392  2018-11-11-17:14:19
# 371393  2018-11-11-17:26:15
# 382051  2018-11-11-18:07:14
# 382052  2018-11-11-18:07:41
#
# [906 rows x 6 columns]

# %%
''' Obs: Nomes da linhas nulos não é um problema, pois se tem o id de identificação delas na coluna linha! '''
# Out:
# ' Obs: Nomes da linhas nulos não é um problema, pois se tem o id de identificação delas na coluna linha! '

# %% [markdown]
# ### 1.1.2 Tratamento da base para localização de validações fora de terminais

# %%
# Memoria liberou 0.2 gb
mes_tudo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24919015 entries, 0 to 929957
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  object
#  4   tipo_cartao    object
#  5   momento        object
# dtypes: int32(2), object(4)
# memory usage: 1.1+ GB

# %%
mes1 = mes_tudo

# %%
# Excluindo explicitamente variavel com bilhetagem desnecessária
del mes_tudo

# %%
mes1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24919015 entries, 0 to 929957
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  object
#  4   tipo_cartao    object
#  5   momento        object
# dtypes: int32(2), object(4)
# memory usage: 1.1+ GB

# %%
mes1["momento"] = pd.to_datetime(mes1["momento"], format= '%Y-%m-%d-%H:%M:%S')

# %%
# Removendo dados nulos na coluna prefixo_carro
mes_ = mes1.dropna(subset = ['prefixo_carro'])

# %%
# Excluindo explicitamente variavel com bilhetagem desnecessária
del mes1

# %%
# Removendo identificação de veiculos com caracteris da coluna de prefixo_carro
mes = mes_[pd.to_numeric(mes_['prefixo_carro'], errors='coerce').notnull()]

# %%
# Trasnformando coluna de prefixo carro em inteiro
mes['prefixo_carro'] = mes['prefixo_carro'].astype('int32')
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\119345733.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mes['prefixo_carro'] = mes['prefixo_carro'].astype('int32')

# %%
mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24891059 entries, 0 to 929957
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  int32
#  4   tipo_cartao    object
#  5   momento        datetime64[ns]
# dtypes: datetime64[ns](1), int32(3), object(2)
# memory usage: 1.0+ GB

# %%
# Última versão do df MES
mes
# Out:
#              id  linha            nome_linha  prefixo_carro      tipo_cartao  \
# 0       7407715     21  Luc. Cavalca./Papicu           2018  Vale transporte
# 1       4526990     21  Luc. Cavalca./Papicu           2018  Vale transporte
# 2       6084812     21  Luc. Cavalca./Papicu           2018  Vale transporte
# 3       7341826     21  Luc. Cavalca./Papicu           2018  Vale transporte
# 4       7261888     21  Luc. Cavalca./Papicu           2018  Vale transporte
# ...         ...    ...                   ...            ...              ...
# 929953        0    114  Cj Nova Assuncao/Fra          21710          Inteira
# 929954        0    114  Cj Nova Assuncao/Fra          21710          Inteira
# 929955        0    114  Cj Nova Assuncao/Fra          21710          Inteira
# 929956        0    114  Cj Nova Assuncao/Fra          21710          Inteira
# 929957        0    114  Cj Nova Assuncao/Fra          21710          Inteira
#
#                    momento
# 0      2018-11-01 23:57:37
# 1      2018-11-02 00:01:25
# 2      2018-11-01 22:45:20
# 3      2018-11-01 22:45:36
# 4      2018-11-01 22:52:44
# ...                    ...
# 929953 2018-11-30 05:54:09
# 929954 2018-11-30 05:54:35
# 929955 2018-11-30 05:59:20
# 929956 2018-11-30 06:04:11
# 929957 2018-11-30 05:17:14
#
# [24891059 rows x 6 columns]

# %%
24891059-3289838
# Out:
# 21601221

# %% [markdown]
# ## 1.2 leitura da base dicionário e identificação de validações em terminais

# %% [markdown]
# ### 1.2.1 leitura e tratamento da base dicionário

# %%
# df', abaixo:
d1 = pd.read_csv('veiculos2018.csv', sep= ';')

# %%
# Mostrando Df
display(d1)
# Out:
#       id_veiculo cod_veiculo
# 0          42095      20274M
# 1          42080       20957
# 2          41971       26815
# 3          41970       26821
# 4          41969       26819
# ...          ...         ...
# 2036       32033       36006
# 2037       32032       36004
# 2038       32031       36003
# 2039       32030       36002
# 2040       32029       36001
#
# [2041 rows x 2 columns]

# %%
''' Verificamos dados que contem dados com strings '''
# Out:
# ' Verificamos dados que contem dados com strings '

# %%
''' IREMOS REMOVER ESSES DADOS E DEPOIS VERIFICAR, MAS A PRINCIPIO IREMOS VER OS DUPLICADOS DA BASE BRUTA: '''
# Out:
# ' IREMOS REMOVER ESSES DADOS E DEPOIS VERIFICAR, MAS A PRINCIPIO IREMOS VER OS DUPLICADOS DA BASE BRUTA: '

# %%
# visualizando DUPLICADOS 
d1[d1['cod_veiculo'].duplicated(keep=False)]
# Out:
#       id_veiculo cod_veiculo
# 334        37922       26103
# 1897       32305       26103

# %%
''' NÃO FAZ SENTIDO TER MAIS DE UMA IDENTIFCAÇÃO PARA UM MESMO VEICULO NA BASE DO GPS, LOGO, OS DADOS DA COLUNA COD_VEICULO DEVEM TER VALORES UNICOS! '''
# Out:
# ' NÃO FAZ SENTIDO TER MAIS DE UMA IDENTIFCAÇÃO PARA UM MESMO VEICULO NA BASE DO GPS, LOGO, OS DADOS DA COLUNA COD_VEICULO DEVEM TER VALORES UNICOS! '

# %%
d1.drop_duplicates(inplace=True)

# %%
# Removendo identificação de veiculos com caracteres da coluna de cod_veiculo
d01 = d1[pd.to_numeric(d1['cod_veiculo'], errors='coerce').notnull()]

# %%
d01['cod_veiculo'] = d01['cod_veiculo'].astype('int32')
d01['id_veiculo'] = d01['id_veiculo'].astype('int32')
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1785617397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d01['cod_veiculo'] = d01['cod_veiculo'].astype('int32')
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1785617397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d01['id_veiculo'] = d01['id_veiculo'].astype('int32')

# %% [markdown]
# ### 1.2.2 Identificação de validações em terminais

# %%
# Verificando dados que estão na bilhetagem (prefixo_carro), mas não estão no dicionário e consequentemente não estão no GPS
dados_apenas_em_mes_ = mes[~mes['prefixo_carro'].isin(d01['cod_veiculo'])]

# %%
dados_apenas_em_mes_
# Out:
#              id  linha      nome_linha  prefixo_carro      tipo_cartao  \
# 1296    7165982    841      HGF/PAPICU           2131  Vale transporte
# 1297    7455408    841      HGF/PAPICU           2131  Vale transporte
# 1298    7360199    841      HGF/PAPICU           2131  Vale transporte
# 1299    7360332    841      HGF/PAPICU           2131  Vale transporte
# 1300    7119083    841      HGF/PAPICU           2131  Vale transporte
# ...         ...    ...             ...            ...              ...
# 928070        0      5  TERMINAL LAGOA          42986          Inteira
# 928071        0      5  TERMINAL LAGOA          42986          Inteira
# 928072        0      5  TERMINAL LAGOA          42986          Inteira
# 928073        0      5  TERMINAL LAGOA          42986          Inteira
# 928074        0      5  TERMINAL LAGOA          42986          Inteira
#
#                    momento
# 1296   2018-11-01 16:22:49
# 1297   2018-11-01 16:24:21
# 1298   2018-11-01 16:24:31
# 1299   2018-11-01 23:22:33
# 1300   2018-11-01 22:56:38
# ...                    ...
# 928070 2018-11-30 01:15:58
# 928071 2018-11-30 01:16:35
# 928072 2018-11-30 01:36:28
# 928073 2018-11-30 01:47:36
# 928074 2018-11-30 00:03:20
#
# [3289838 rows x 6 columns]

# %%
dados_apenas_em_mes_.isnull().sum()
# Out:
# id               0
# linha            0
# nome_linha       0
# prefixo_carro    0
# tipo_cartao      0
# momento          0
# dtype: int64

# %%
# Verificando dados que estão na bilhetagem (prefixo_carro), mas não estão no dicionário e consequentemente não estão no GPS
dados_apenas_em_mes_ = mes[~mes['prefixo_carro'].isin(d01['cod_veiculo'])]# Filtrando linhas em terminais
df_terminais_filtro_01 = dados_apenas_em_mes_[dados_apenas_em_mes_['nome_linha'].str.contains( 'TERMINAL')]

#  Por inspeção foi identificado outra nomelcatura para o terminal (ANT.BEZERRA)
df_terminais_filtro_02  = dados_apenas_em_mes_[dados_apenas_em_mes_['nome_linha'].str.contains('TERM.ANT.BEZERRA')]

# %%
# Verificando quantidade de validações em terminais filtro_01
df_terminais_filtro_01['nome_linha'].value_counts()
# Out:
# TERMINAL PARANGABA    397792
# TERMINAL MESSEJANA    175306
# TERMINAL SIQUEIRA     112602
# TERMINAL PAPICU        70957
# TERMINAL LAGOA         68089
# TERMINAL CEARA         66161
# Name: nome_linha, dtype: int64

# %%
# Verificando quantidade de validações em terminais filtro_02
df_terminais_filtro_02['nome_linha'].value_counts()
# Out:
# TERM.ANT.BEZERRA    218982
# Name: nome_linha, dtype: int64

# %%
# JUNTANDO DADOS DE TERMINAIS EM UMA UNICA BASE 
df_terminais = pd.concat([df_terminais_filtro_01,df_terminais_filtro_02])

# %%
del df_terminais_filtro_01
del df_terminais_filtro_02

# %%
# Base com TERMINAIS
df_terminais
# Out:
#              id  linha          nome_linha  prefixo_carro tipo_cartao  \
# 41777   2277640      3  TERMINAL PARANGABA          12988   Estudante
# 41778    393112      3  TERMINAL PARANGABA          12988   Estudante
# 41779   7334874      3  TERMINAL PARANGABA          12988   Estudante
# 41780   7505147      3  TERMINAL PARANGABA          12988   Estudante
# 41781   6970753      3  TERMINAL PARANGABA          12988   Estudante
# ...         ...    ...                 ...            ...         ...
# 886252        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 886253        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 886254        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 886255        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 886256        0      1    TERM.ANT.BEZERRA          36976     Inteira
#
#                    momento
# 41777  2018-11-01 22:59:22
# 41778  2018-11-01 21:43:06
# 41779  2018-11-01 22:03:26
# 41780  2018-11-01 22:14:35
# 41781  2018-11-01 18:02:04
# ...                    ...
# 886252 2018-11-30 05:54:44
# 886253 2018-11-30 05:55:13
# 886254 2018-11-30 05:55:22
# 886255 2018-11-30 05:55:51
# 886256 2018-11-30 05:59:11
#
# [1109889 rows x 6 columns]

# %%
df_terminais['nome_linha'].unique()
# Out:
# array(['TERMINAL PARANGABA', 'TERMINAL PAPICU', 'TERMINAL MESSEJANA',
#        'TERMINAL SIQUEIRA', 'TERMINAL CEARA', 'TERMINAL LAGOA',
#        'TERM.ANT.BEZERRA'], dtype=object)

# %%
''' É possivel verificar que o terminal siqueira tinha dados nulos, mas ele é filtrado e fica na varaivel df_terminais, logo a localização dele sera incluso ja nessa varivel! '''
# Out:
# ' É possivel verificar que o terminal siqueira tinha dados nulos, mas ele é filtrado e fica na varaivel df_terminais, logo a localização dele sera incluso ja nessa varivel! '

# %%
''' Sendo assim é possivel verificar as validações por meio do mesmo id_veiculo e usando o criteiro de tempo, ja os dados dos terminais será usado o metodo de localização desses dados na variavel df_terminais! '''
# Out:
# ' Sendo assim é possivel verificar as validações por meio do mesmo id_veiculo e usando o criteiro de tempo, ja os dados dos terminais será usado o metodo de localização desses dados na variavel df_terminais! '

# %%
''' PARA PARADAS EM BRT´S NÃO SE TEM O NOME DAS ESTACOES AO LONGO DAS LINAS, LOGO NÃO SERÁ POSSIVEL LOCALIZAR ESSAS VALIDAÇÕES!'''
# Out:
# ' PARA PARADAS EM BRT´S NÃO SE TEM O NOME DAS ESTACOES AO LONGO DAS LINAS, LOGO NÃO SERÁ POSSIVEL LOCALIZAR ESSAS VALIDAÇÕES!'

# %% [markdown]
# ## 1.3 leitura do base - GPS (Tratamento INICIAL)

# %%
import pandas as pd

# Definindo o número de linhas que você deseja ler
numero_de_linhas_para_ler = 45000000  # Substitua pelo número desejado
dtype_specification = {'longitude': 'float32', 'latitude': 'float32', 'vehicle_vehicleid': 'int32'}

# Usando o pandas para ler o CSV, limitando o número de linhas com a opção nrows
mes_ate_45_milhoes = pd.read_csv('Paint112018.csv',usecols=['latitude', 'longitude', 'metrictimestamp', 'vehicle_vehicleid'], dtype=dtype_specification, nrows=numero_de_linhas_para_ler)

# %%
# Lendo restante do arquivo
mes_resto = pd.read_csv('Paint112018.csv', usecols=['latitude', 'longitude','metrictimestamp', 'vehicle_vehicleid'],dtype=dtype_specification, skiprows=range(1, numero_de_linhas_para_ler + 1))

# %%
# Juntando em um mesmo df
GPS_I_H =  pd.concat([mes_ate_45_milhoes, mes_resto])

# %%
# Excluindo explicitamente variavel com dados do GPS separados
del mes_ate_45_milhoes
del mes_resto

# %%
display(GPS_I_H.iloc[275])
# Out:
# latitude            -3.725625e+00
# longitude           -3.855716e+01
# metrictimestamp      2.018120e+13
# vehicle_vehicleid    3.909400e+04
# Name: 275, dtype: float64

# %%
GPS_I_H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109792980 entries, 0 to 64792979
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   latitude           float32
#  1   longitude          float32
#  2   metrictimestamp    int64
#  3   vehicle_vehicleid  int32
# dtypes: float32(2), int32(1), int64(1)
# memory usage: 2.9 GB

# %%
# FORMATANDO metrictimestamp do (GPS)
GPS_I_H['momento'] = pd.to_datetime(GPS_I_H['metrictimestamp'],format= '%Y%m%d%H%M%S')

# %%
GPS_I_H.drop("metrictimestamp", axis= 1, inplace= True)

# %%
# Renomear coluna de momento de vehicle_vehicleid para id_veiculo:
GPS_I_H.columns=['latitude', 'longitude','id_veiculo', 'momento']

# %%
# Colocando valores em ordem
GPS_I_H.sort_values('momento', inplace= True)

# %% [markdown]
# # 2.0 Junção da bilhetagem com o dicionário

# %%
# Filtrando que estão na bilhetagem e estão no dicionário e consequentemente estão no GPS
dados_em_mes_GPS_ = mes[mes['prefixo_carro'].isin(d01['cod_veiculo'])]

# %%
dados_em_mes_GPS_.reset_index(inplace=True)

# %%
dados_em_mes_GPS_.drop(columns=['index'], inplace=True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\2342148454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_em_mes_GPS_.drop(columns=['index'], inplace=True)

# %%
dados_em_mes_GPS_.isnull().sum()
# Out:
# id                 0
# linha              0
# nome_linha       906
# prefixo_carro      0
# tipo_cartao        0
# momento            0
# dtype: int64

# %%
dados_em_mes_GPS_
# Out:
#                id  linha            nome_linha  prefixo_carro  \
# 0         7407715     21  Luc. Cavalca./Papicu           2018
# 1         4526990     21  Luc. Cavalca./Papicu           2018
# 2         6084812     21  Luc. Cavalca./Papicu           2018
# 3         7341826     21  Luc. Cavalca./Papicu           2018
# 4         7261888     21  Luc. Cavalca./Papicu           2018
# ...           ...    ...                   ...            ...
# 21601216        0    114  Cj Nova Assuncao/Fra          21710
# 21601217        0    114  Cj Nova Assuncao/Fra          21710
# 21601218        0    114  Cj Nova Assuncao/Fra          21710
# 21601219        0    114  Cj Nova Assuncao/Fra          21710
# 21601220        0    114  Cj Nova Assuncao/Fra          21710
#
#               tipo_cartao             momento
# 0         Vale transporte 2018-11-01 23:57:37
# 1         Vale transporte 2018-11-02 00:01:25
# 2         Vale transporte 2018-11-01 22:45:20
# 3         Vale transporte 2018-11-01 22:45:36
# 4         Vale transporte 2018-11-01 22:52:44
# ...                   ...                 ...
# 21601216          Inteira 2018-11-30 05:54:09
# 21601217          Inteira 2018-11-30 05:54:35
# 21601218          Inteira 2018-11-30 05:59:20
# 21601219          Inteira 2018-11-30 06:04:11
# 21601220          Inteira 2018-11-30 05:17:14
#
# [21601221 rows x 6 columns]

# %%
# Acrescentando dicionário
mes_d1 = dados_em_mes_GPS_.merge(d01, left_on= 'prefixo_carro', right_on='cod_veiculo', how= 'left')

# %%
mes_d1.isnull().sum()
# Out:
# id                 0
# linha              0
# nome_linha       906
# prefixo_carro      0
# tipo_cartao        0
# momento            0
# id_veiculo         0
# cod_veiculo        0
# dtype: int64

# %%
# Base da Bilhetagem adicionado o dicionario
mes_d1
# Out:
#                id  linha            nome_linha  prefixo_carro  \
# 0         7407715     21  Luc. Cavalca./Papicu           2018
# 1         4526990     21  Luc. Cavalca./Papicu           2018
# 2         6084812     21  Luc. Cavalca./Papicu           2018
# 3         7341826     21  Luc. Cavalca./Papicu           2018
# 4         7261888     21  Luc. Cavalca./Papicu           2018
# ...           ...    ...                   ...            ...
# 21610576        0    114  Cj Nova Assuncao/Fra          21710
# 21610577        0    114  Cj Nova Assuncao/Fra          21710
# 21610578        0    114  Cj Nova Assuncao/Fra          21710
# 21610579        0    114  Cj Nova Assuncao/Fra          21710
# 21610580        0    114  Cj Nova Assuncao/Fra          21710
#
#               tipo_cartao             momento  id_veiculo  cod_veiculo
# 0         Vale transporte 2018-11-01 23:57:37       32174         2018
# 1         Vale transporte 2018-11-02 00:01:25       32174         2018
# 2         Vale transporte 2018-11-01 22:45:20       32174         2018
# 3         Vale transporte 2018-11-01 22:45:36       32174         2018
# 4         Vale transporte 2018-11-01 22:52:44       32174         2018
# ...                   ...                 ...         ...          ...
# 21610576          Inteira 2018-11-30 05:54:09       38563        21710
# 21610577          Inteira 2018-11-30 05:54:35       38563        21710
# 21610578          Inteira 2018-11-30 05:59:20       38563        21710
# 21610579          Inteira 2018-11-30 06:04:11       38563        21710
# 21610580          Inteira 2018-11-30 05:17:14       38563        21710
#
# [21610581 rows x 8 columns]

# %%
mes_d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21610581 entries, 0 to 21610580
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  int32
#  4   tipo_cartao    object
#  5   momento        datetime64[ns]
#  6   id_veiculo     int32
#  7   cod_veiculo    int32
# dtypes: datetime64[ns](1), int32(5), object(2)
# memory usage: 1.0+ GB

# %%
# Criando df somente colunas necessátrias para a integração no tópico 03!
mes_geo = mes_d1.sort_values('momento')

# %%
del mes_d1

# %%
# Reiniciando a contagem dos index
mes_geo.reset_index(inplace=True)

# %%
# REMOVENDO COLUNA DESNECESSÁRIA!
mes_georr = mes_geo.drop(['index'], axis=1)

# %%
mes_georr['id_veiculo'] = mes_georr['id_veiculo'].astype('int32')

# %%
mes_georr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21610581 entries, 0 to 21610580
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  int32
#  4   tipo_cartao    object
#  5   momento        datetime64[ns]
#  6   id_veiculo     int32
#  7   cod_veiculo    int32
# dtypes: datetime64[ns](1), int32(5), object(2)
# memory usage: 906.8+ MB

# %%
del mes_geo

# %% [markdown]
# # 3.0 Integração da coordenada aproxima na bilhetagem

# %% [markdown]
# ## 3.1 Coordenada aproximada do ônibus na bilhetagem (localização de validações fora de terminais e BRT)

# %%
# Coordenada mais proxima do ônibus é extraída da base de GPS e integrada na base da bilhetagem (SOMENTE COLUMAS MOMENTO E ID)
mes_d1_GPS_ = pd.merge_asof(mes_georr, GPS_I_H, left_on='momento', right_on='momento', by='id_veiculo', direction ='nearest')

# %%
mes_d1_GPS_.isnull().sum()
# Out:
# id                     0
# linha                  0
# nome_linha           906
# prefixo_carro          0
# tipo_cartao            0
# momento                0
# id_veiculo             0
# cod_veiculo            0
# latitude         1619385
# longitude        1619385
# dtype: int64

# %%
mes_d1_GPS_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21610581 entries, 0 to 21610580
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int32
#  1   linha          int32
#  2   nome_linha     object
#  3   prefixo_carro  int32
#  4   tipo_cartao    object
#  5   momento        datetime64[ns]
#  6   id_veiculo     int32
#  7   cod_veiculo    int32
#  8   latitude       float32
#  9   longitude      float32
# dtypes: datetime64[ns](1), float32(2), int32(5), object(2)
# memory usage: 1.2+ GB

# %%
# Removedo dados duplicados de validações devido merge com duas associações de prefixo_carro com cod_veiculo do dicionario
mes_d1_GPS = mes_d1_GPS_.drop_duplicates(['id', 'momento', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao', 'cod_veiculo'])

# %%
''' FORAM REMOVIDAS AS VALIDAÇÕES DE UM MESMO USUARIO, PARA O MESMO MOMENTO E MESMO VEICULO UTILIZADO (identificação_dicionario), POIS POSSIVELMENTE É O DAODS DUPLICADO NO MERGE DA BILHETAGEM COM O DICIONARIO! '''
# Out:
# ' FORAM REMOVIDAS AS VALIDAÇÕES DE UM MESMO USUARIO, PARA O MESMO MOMENTO E MESMO VEICULO UTILIZADO (identificação_dicionario), POIS POSSIVELMENTE É O DAODS DUPLICADO NO MERGE DA BILHETAGEM COM O DICIONARIO! '

# %%
mes_d1_GPS.reset_index(inplace=True)
mes_d1_GPS.drop(['index'], inplace=True, axis=1)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1461081780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mes_d1_GPS.drop(['index'], inplace=True, axis=1)

# %%
# Base da bilhetagem localizada 
mes_d1_GPS
# Out:
#                id  linha            nome_linha  prefixo_carro  \
# 0         6495289     95  Corujao/Cj Pref. Jos          26407
# 1               0     54  Corujao/Praia do Fut          30426
# 2         6730926     57  Corujao/Jardim Irace          35120
# 3         4841184     57  Corujao/Jardim Irace          35120
# 4         7317420     90  Corujao/Montese               12219
# ...           ...    ...                   ...            ...
# 21601180  6324055     56  Corujao/Grande Circu           2313
# 21601181  7542863     56  Corujao/Grande Circu           2313
# 21601182  7114601     56  Corujao/Grande Circu           2313
# 21601183   273038     56  Corujao/Grande Circu           2313
# 21601184        0     56  Corujao/Grande Circu           2313
#
#               tipo_cartao             momento  id_veiculo  cod_veiculo  \
# 0              Gratuidade 2018-11-01 00:01:21       32409        26407
# 1                 Inteira 2018-11-01 00:11:05       33276        30426
# 2         Vale transporte 2018-11-01 00:12:16       33801        35120
# 3         Vale transporte 2018-11-01 00:12:30       33801        35120
# 4         Vale transporte 2018-11-01 00:13:58       33637        12219
# ...                   ...                 ...         ...          ...
# 21601180  Vale transporte 2018-12-01 04:45:32       32786         2313
# 21601181  Vale transporte 2018-12-01 04:48:07       32786         2313
# 21601182  Vale transporte 2018-12-01 04:48:24       32786         2313
# 21601183        Estudante 2018-12-01 04:48:33       32786         2313
# 21601184          Inteira 2018-12-01 04:48:46       32786         2313
#
#           latitude  longitude
# 0        -3.838164 -38.558586
# 1        -3.740973 -38.539021
# 2        -3.722791 -38.530235
# 3        -3.722791 -38.530235
# 4        -3.780263 -38.570004
# ...            ...        ...
# 21601180 -3.803030 -38.503075
# 21601181 -3.803030 -38.503075
# 21601182 -3.803030 -38.503075
# 21601183 -3.803030 -38.503075
# 21601184 -3.803030 -38.503075
#
# [21601185 rows x 10 columns]

# %%
del GPS_I_H

# %% [markdown]
# ## 3.2 Coordenada aproximada dos terminais na bilhetagem

# %% [markdown]
# ### 3.2.1 Importando dados no formato GTFS

# %%
# Reatribuindo variavel com dados de validações em terminais
df_terminais_validacoes = df_terminais

# %%
del df_terminais

# %%
df_terminais_validacoes.reset_index(inplace=True)

# %%
df_terminais_validacoes.drop(['index'], inplace=True, axis=1)

# %%
# BASE COM VALIDAÇÕES FEITAS NOS TERMINAIS 
df_terminais_validacoes
# Out:
#               id  linha          nome_linha  prefixo_carro tipo_cartao  \
# 0        2277640      3  TERMINAL PARANGABA          12988   Estudante
# 1         393112      3  TERMINAL PARANGABA          12988   Estudante
# 2        7334874      3  TERMINAL PARANGABA          12988   Estudante
# 3        7505147      3  TERMINAL PARANGABA          12988   Estudante
# 4        6970753      3  TERMINAL PARANGABA          12988   Estudante
# ...          ...    ...                 ...            ...         ...
# 1109884        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109885        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109886        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109887        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109888        0      1    TERM.ANT.BEZERRA          36976     Inteira
#
#                     momento
# 0       2018-11-01 22:59:22
# 1       2018-11-01 21:43:06
# 2       2018-11-01 22:03:26
# 3       2018-11-01 22:14:35
# 4       2018-11-01 18:02:04
# ...                     ...
# 1109884 2018-11-30 05:54:44
# 1109885 2018-11-30 05:55:13
# 1109886 2018-11-30 05:55:22
# 1109887 2018-11-30 05:55:51
# 1109888 2018-11-30 05:59:11
#
# [1109889 rows x 6 columns]

# %%
df_terminais_validacoes['nome_linha'].unique()
# Out:
# array(['TERMINAL PARANGABA', 'TERMINAL PAPICU', 'TERMINAL MESSEJANA',
#        'TERMINAL SIQUEIRA', 'TERMINAL CEARA', 'TERMINAL LAGOA',
#        'TERM.ANT.BEZERRA'], dtype=object)

# %%
# Importando base com locais previstos de parada
stops_paradas = pd.read_csv('stops.txt', sep= ',')

# %%
# Removendo colunas desnecessárias do df com paradas 
stops_paradas.drop(columns= ['stop_code', 'stop_desc', 'zone_id', 'stop_url', 'location_type', 'parent_station', 'stop_timezone', 'wheelchair_boarding'], inplace=True)

# %%
stops_paradas
# Out:
#       stop_id                        stop_name  stop_lat   stop_lon
# 0          10       AVENIDA CEL CARVALHO, 1180 -3.702286 -38.590602
# 1        1000        RUA DOR JOAO MOREIRA, 489 -3.722157 -38.528991
# 2        1001        RUA DOR JOAO MOREIRA, 163 -3.723169 -38.526007
# 3        1009   AVENIDA TRISTÃO GONÇALVES, 500 -3.725926 -38.532847
# 4        1010           AVENIDA IMPERADOR, 550 -3.726137 -38.534206
# ...       ...                              ...       ...        ...
# 4533      991   RUA MON CARNEIRO DA CUNHA, 149 -3.724630 -38.541716
# 4534      992          RUA PEDRO PEREIRA, 1530 -3.726388 -38.538707
# 4535      993          RUA CASTRO E SILVA, 950 -3.721771 -38.533664
# 4536      994  AVENIDA PRS CASTELO BRANCO, 615 -3.719262 -38.531967
# 4537      999   AVENIDA PRS CASTELO BRANCO, NI -3.720936 -38.528643
#
# [4538 rows x 4 columns]

# %%
''' POR INSPEÇÃO FOI VERIFICADO QUE A LOCALIZAÇÃO PARA VALIDAÇÃO EM TERMINAIS SÃO NOMEADOS COMO PREÇAS_Nomedoterminal'''
# Out:
# ' POR INSPEÇÃO FOI VERIFICADO QUE A LOCALIZAÇÃO PARA VALIDAÇÃO EM TERMINAIS SÃO NOMEADOS COMO PREÇAS_Nomedoterminal'

# %%
# FILTRANDO LOCAIS DAS PRAÇAS NOS TERMINAIS QUE POSSUEM A LOCCALIZAÇÃO
terminais_geometry_ = stops_paradas[stops_paradas['stop_name'].str.contains('TERM')]

# %%
# Reiniciando a contagem do indice 
terminais_geometry_.reset_index(inplace=True)

# %%
terminais_geometry = terminais_geometry_.drop_duplicates(subset=['stop_name'])

# %%
# Dropando coluna desnecessaria
terminais_geometry.drop(columns=['stop_id'], inplace=True)
terminais_geometry.drop(2, inplace= True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1016374250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terminais_geometry.drop(columns=['stop_id'], inplace=True)
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1016374250.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terminais_geometry.drop(2, inplace= True)

# %%
terminais_geometry.rename(columns={'stop_lat': 'latitude', 'stop_lon': 'longitude'}, inplace=True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1450051314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terminais_geometry.rename(columns={'stop_lat': 'latitude', 'stop_lon': 'longitude'}, inplace=True)

# %%
# Adequando nomes dos terminais para mesclagem
nome_procurado_1 = 'PRAÇA TERMINAL PARANGABA, SN' 
nome_procurado_2 = 'PRAÇA TERMINAL PAPICU, SN' 
nome_procurado_3 = 'PRAÇA TERMINAL MESSEJANA, SN' 
nome_procurado_4 = 'PRAÇA TERMINAL SIQUEIRA, SN' 
nome_procurado_5 = 'PRAÇA TERMINAL CONJUNTO CEARÁ, SN' 
nome_procurado_6 = 'PRAÇA TERMINAL LAGOA, SN' 
nome_procurado_7 = 'PRAÇA TERMINAL ANTONIO BEZERRA, SN'

# Localizando a linha com base no nome e, em seguida, atualizando os valores desejados
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_1, 'stop_name'] = 'TERMINAL PARANGABA' 
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_2, 'stop_name'] = 'TERMINAL PAPICU' 
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_3, 'stop_name'] = 'TERMINAL MESSEJANA' 
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_4, 'stop_name'] = 'TERMINAL SIQUEIRA'  
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_5, 'stop_name'] = 'TERMINAL CEARA'  
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_6, 'stop_name'] = 'TERMINAL LAGOA' 
terminais_geometry.loc[terminais_geometry['stop_name'] == nome_procurado_7, 'stop_name'] = 'TERM.ANT.BEZERRA'

# %%
terminais_geometry.drop(columns=['index'], inplace=True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1562193393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terminais_geometry.drop(columns=['index'], inplace=True)

# %%
# BASE COM LOCALIZAÇÃO DOS TERMINAIS 
terminais_geometry
# Out:
#              stop_name  latitude  longitude
# 0   TERMINAL MESSEJANA -3.831484 -38.501933
# 3       TERMINAL LAGOA -3.770631 -38.570298
# 4       TERMINAL CEARA -3.772986 -38.607545
# 6    TERMINAL SIQUEIRA -3.789329 -38.586833
# 8   TERMINAL PARANGABA -3.776384 -38.563162
# 9      TERMINAL PAPICU -3.738568 -38.484761
# 13    TERM.ANT.BEZERRA -3.737439 -38.583885

# %% [markdown]
# ### 3.2.2 Adicioando localização nas validações dos terminais
# ''' Com a localização dos terminais ja determindas, é possivel adiconar essa informações nas validações da bilhetagem nesses locais '''

# %%
# MESCLANDO PELO NOME DA LINHA DA BILHETEGEM E O NOME DA PARADA CORRESPONDENTE AS SUAS RESPECTIVAS LINHAS 
mes_terminais_geometry = df_terminais_validacoes.merge(terminais_geometry, left_on= 'nome_linha', right_on='stop_name')

# %%
# Reiniciando a contagem do indice e dropando index
mes_terminais_geometry.reset_index(inplace=True)
mes_terminais_geometry.drop(columns=['index', 'stop_name'], inplace=True)

# %%
# CRIANDO COLUNA ID_LINHA E COD_VEICULO PARA COLOCAR DADOS DE VALIDAÇÕES LOCALIZADOS EM UMA UNICA BASE!
mes_terminais_geometry['id_veiculo'] = 'validacao_terminal'
mes_terminais_geometry['cod_veiculo'] = 'validacao_terminal'

# %%
# Reordenando colunas 
dados_terminais_geo = mes_terminais_geometry[['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao', 'momento', 'id_veiculo', 'cod_veiculo', 'latitude', 'longitude']]

# %%
del mes_terminais_geometry

# %%
# Base com dados da bilhetagem localizada em terminais
dados_terminais_geo
# Out:
#               id  linha          nome_linha  prefixo_carro tipo_cartao  \
# 0        2277640      3  TERMINAL PARANGABA          12988   Estudante
# 1         393112      3  TERMINAL PARANGABA          12988   Estudante
# 2        7334874      3  TERMINAL PARANGABA          12988   Estudante
# 3        7505147      3  TERMINAL PARANGABA          12988   Estudante
# 4        6970753      3  TERMINAL PARANGABA          12988   Estudante
# ...          ...    ...                 ...            ...         ...
# 1109884        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109885        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109886        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109887        0      1    TERM.ANT.BEZERRA          36976     Inteira
# 1109888        0      1    TERM.ANT.BEZERRA          36976     Inteira
#
#                     momento          id_veiculo         cod_veiculo  latitude  \
# 0       2018-11-01 22:59:22  validacao_terminal  validacao_terminal -3.776384
# 1       2018-11-01 21:43:06  validacao_terminal  validacao_terminal -3.776384
# 2       2018-11-01 22:03:26  validacao_terminal  validacao_terminal -3.776384
# 3       2018-11-01 22:14:35  validacao_terminal  validacao_terminal -3.776384
# 4       2018-11-01 18:02:04  validacao_terminal  validacao_terminal -3.776384
# ...                     ...                 ...                 ...       ...
# 1109884 2018-11-30 05:54:44  validacao_terminal  validacao_terminal -3.737439
# 1109885 2018-11-30 05:55:13  validacao_terminal  validacao_terminal -3.737439
# 1109886 2018-11-30 05:55:22  validacao_terminal  validacao_terminal -3.737439
# 1109887 2018-11-30 05:55:51  validacao_terminal  validacao_terminal -3.737439
# 1109888 2018-11-30 05:59:11  validacao_terminal  validacao_terminal -3.737439
#
#          longitude
# 0       -38.563162
# 1       -38.563162
# 2       -38.563162
# 3       -38.563162
# 4       -38.563162
# ...            ...
# 1109884 -38.583885
# 1109885 -38.583885
# 1109886 -38.583885
# 1109887 -38.583885
# 1109888 -38.583885
#
# [1109889 rows x 10 columns]

# %% [markdown]
# ## 3.3 Coordenada das demais (algumas de BRT´s e outras validações na bilhetagem
# ''' O pressuposto inicial é que as validações que não possuem um id de identifcação dos veiculos correspondentes no GPS (pelo dicionario) são aquelas que os usuarios validaram no terminais, algumas podem ser de estações de BRT e de casos em que simplismente para os USUARIOS EM QUE A IDENTIFCAÇÃO DO VEICULOS NÃO POSSUI UM CORRESPONDENTE NO GPS, DEVIDO A FALTA DE UMA ASSOCIAÇÃO NO DICIONARIO, como ja foi abordado a localização das validações em terminais, basta realizar uma abordagem com as demais! '''

# %% [markdown]
# ### 3.3.1 Identificando outras validações (possivel estação BRT´s e nos demais casos
# ''' Identifcação das validações em possiveis estaçoes de BRT e nos demais casos que não possuiam um veiculo correspondente no GPS'''

# %%
# Reatribuindo variavel com dados que estão na bilhetagem, mas não estão no dicionário e consequentemente não estão no GPS
dados_apenas_em_mes = dados_apenas_em_mes_

# %%
del dados_apenas_em_mes_

# %%
''' Foi utilizado a base "mes" pois ela tinha a coluna como numerica para comparação '''
# Out:
# ' Foi utilizado a base "mes" pois ela tinha a coluna como numerica para comparação '

# %%
# Base com dados de validaçoes em terminais e em BRT
dados_apenas_em_mes
# Out:
#              id  linha      nome_linha  prefixo_carro      tipo_cartao  \
# 1296    7165982    841      HGF/PAPICU           2131  Vale transporte
# 1297    7455408    841      HGF/PAPICU           2131  Vale transporte
# 1298    7360199    841      HGF/PAPICU           2131  Vale transporte
# 1299    7360332    841      HGF/PAPICU           2131  Vale transporte
# 1300    7119083    841      HGF/PAPICU           2131  Vale transporte
# ...         ...    ...             ...            ...              ...
# 928070        0      5  TERMINAL LAGOA          42986          Inteira
# 928071        0      5  TERMINAL LAGOA          42986          Inteira
# 928072        0      5  TERMINAL LAGOA          42986          Inteira
# 928073        0      5  TERMINAL LAGOA          42986          Inteira
# 928074        0      5  TERMINAL LAGOA          42986          Inteira
#
#                    momento
# 1296   2018-11-01 16:22:49
# 1297   2018-11-01 16:24:21
# 1298   2018-11-01 16:24:31
# 1299   2018-11-01 23:22:33
# 1300   2018-11-01 22:56:38
# ...                    ...
# 928070 2018-11-30 01:15:58
# 928071 2018-11-30 01:16:35
# 928072 2018-11-30 01:36:28
# 928073 2018-11-30 01:47:36
# 928074 2018-11-30 00:03:20
#
# [3289838 rows x 6 columns]

# %%
# Dropando dados de terminais pois eles ja foram filtrados em uma base propria (OBS: O NOME SERÁ DADOS_BRT, MAS NÃO NECESSPARIAMENTE SÃO TODOS DE BRT´S!), MA
dados_brt_ = dados_apenas_em_mes[~dados_apenas_em_mes['nome_linha'].str.contains('TERMINAL', case=False)]
dados_brt = dados_brt_[~dados_brt_['nome_linha'].str.contains('TERM.ANT', case=False)]

# %%
dados_brt.reset_index(inplace=True)
dados_brt.drop(columns=['index'], inplace=True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\3731155808.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_brt.drop(columns=['index'], inplace=True)

# %%
# BASE COM DADOS DE VALIDAÇÕES SOMENTE PRESENTES NA BILHETAGEM (veiculos sem identifcação no dicionario)
dados_brt
# Out:
#               id  linha           nome_linha  prefixo_carro      tipo_cartao  \
# 0        7165982    841           HGF/PAPICU           2131  Vale transporte
# 1        7455408    841           HGF/PAPICU           2131  Vale transporte
# 2        7360199    841           HGF/PAPICU           2131  Vale transporte
# 3        7360332    841           HGF/PAPICU           2131  Vale transporte
# 4        7119083    841           HGF/PAPICU           2131  Vale transporte
# ...          ...    ...                  ...            ...              ...
# 2179944        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179945        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179946        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179947        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179948        0    728  JOSE WALTER/ CENTRO          67252          Inteira
#
#                     momento
# 0       2018-11-01 16:22:49
# 1       2018-11-01 16:24:21
# 2       2018-11-01 16:24:31
# 3       2018-11-01 23:22:33
# 4       2018-11-01 22:56:38
# ...                     ...
# 2179944 2018-11-30 07:28:01
# 2179945 2018-11-30 07:34:25
# 2179946 2018-11-30 07:40:20
# 2179947 2018-11-30 07:41:30
# 2179948 2018-11-30 07:46:19
#
# [2179949 rows x 6 columns]

# %%
# Dados das linhas existentes 
dados_brt['linha'].unique()
# Out:
# array([841, 610,  12, 619, 681, 806,  68,   4, 725, 712,  80, 703, 348,
#        318, 753, 728, 754, 710, 757, 713,  87, 375, 605, 407, 333, 346,
#        406, 629, 329, 311, 709, 752, 755, 762, 323, 706, 243, 324, 676,
#        631, 221, 657, 690, 686, 386, 646, 980,  27, 335, 357, 635, 456,
#        343, 401,  86,  50,  20, 639, 645, 670, 637,  15, 376, 382, 392,
#        399, 317,  72,  21,  74,  56, 379, 366, 653, 211,  29, 115, 342,
#        381, 466, 212,  32,  43, 621, 213, 372, 613, 993,  41, 618, 767,
#         16, 606,  53,  55, 102, 377, 361, 642, 628, 390,  98, 680, 345,
#        641,  99, 355, 622, 640,  11,  92,  73, 632, 101, 627,  31,  24,
#         70, 855, 302, 974, 300,  75, 336, 174, 395])

# %%
'''OU SEJA, EXISTEM VALIDAÇÕES DE DIVERSAS LINHAS QUE NÃO TEM UM VEICULO CORRESPONDENTE NO GPS E NÃO SÃO VALIDAÇÕES EM TERMINAIS'''
# Out:
# 'OU SEJA, EXISTEM VALIDAÇÕES DE DIVERSAS LINHAS QUE NÃO TEM UM VEICULO CORRESPONDENTE NO GPS E NÃO SÃO VALIDAÇÕES EM TERMINAIS'

# %% [markdown]
# ### 3.3.2 Associação com o horario programado para localizar as validações em BRT´s e as demais
# ''' Dados de GTFS, possuem dados de localização das paradas e da viagens programdas, assim é possivem associar para uma mesma linha, e pelo horario mais proximo da validação com o programado de passagem para identificação do possivel local de validação '''

# %%
# Printando novamente dados com locias das paradas
stops_paradas
# Out:
#       stop_id                        stop_name  stop_lat   stop_lon
# 0          10       AVENIDA CEL CARVALHO, 1180 -3.702286 -38.590602
# 1        1000        RUA DOR JOAO MOREIRA, 489 -3.722157 -38.528991
# 2        1001        RUA DOR JOAO MOREIRA, 163 -3.723169 -38.526007
# 3        1009   AVENIDA TRISTÃO GONÇALVES, 500 -3.725926 -38.532847
# 4        1010           AVENIDA IMPERADOR, 550 -3.726137 -38.534206
# ...       ...                              ...       ...        ...
# 4533      991   RUA MON CARNEIRO DA CUNHA, 149 -3.724630 -38.541716
# 4534      992          RUA PEDRO PEREIRA, 1530 -3.726388 -38.538707
# 4535      993          RUA CASTRO E SILVA, 950 -3.721771 -38.533664
# 4536      994  AVENIDA PRS CASTELO BRANCO, 615 -3.719262 -38.531967
# 4537      999   AVENIDA PRS CASTELO BRANCO, NI -3.720936 -38.528643
#
# [4538 rows x 4 columns]

# %%
# Importando base com horarios previstos de parada  
stop_times = pd.read_csv('stop_times.txt', sep= ',')

# Importando dados com viagens programadas de cada linha 
trips = pd.read_csv('trips.txt', sep=",")

# %%
# Removendo colunas desnecessárias do df com paradas 
stop_times.drop(columns= ['stop_headsign', 'pickup_type', 'drop_off_type', 'shape_dist_traveled'], inplace=True)

# %%
stop_times
# Out:
#                   trip_id arrival_time departure_time  stop_id  stop_sequence
# 0        D011-T01V01B01-I     05:13:00       05:13:00     3500              1
# 1        D011-T01V01B01-I     05:15:00       05:15:00     1013              2
# 2        D011-T01V01B01-I     05:16:00       05:16:00     1015              3
# 3        D011-T01V01B01-I     05:17:00       05:17:00     4251              4
# 4        D011-T01V01B01-I     05:18:00       05:18:00      990              5
# ...                   ...          ...            ...      ...            ...
# 2581120  U920-T06V07B02-I     19:38:00       19:38:00     6079              3
# 2581121  U920-T06V07B02-V     18:44:00       18:44:00     6079              1
# 2581122  U920-T06V07B02-V     19:09:00       19:09:00     5422              2
# 2581123  U920-T06V08B02-V     19:38:00       19:38:00     6079              1
# 2581124  U920-T06V08B02-V     20:03:00       20:03:00     5422              2
#
# [2581125 rows x 5 columns]

# %%
# Acrescetando dados das paradas pela mesmo stop_id no df de tempos previstos de passagem
merge_pardas_time = pd.merge(stop_times, stops_paradas, left_on='stop_id', right_on='stop_id')

# %%
merge_pardas_time
# Out:
#                   trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0        D011-T01V01B01-I     05:13:00       05:13:00     3500              1
# 1        D011-T01V02B01-I     06:13:00       06:13:00     3500             19
# 2        D011-T01V03B01-I     07:19:00       07:26:00     3500             19
# 3        D011-T01V04B01-I     08:32:00       09:14:00     3500             19
# 4        D011-T01V05B01-I     10:22:00       10:26:00     3500             19
# ...                   ...          ...            ...      ...            ...
# 2581120  U690-T02V01B01-V     10:22:00       10:22:00     6256             13
# 2581121  U690-T03V01B01-I     16:30:00       16:30:00     6256              1
# 2581122  U690-T03V01B01-V     16:30:00       16:30:00     6256             13
# 2581123  U690-T04V01B01-I     20:54:00       20:54:00     6256              1
# 2581124  U690-T04V01B01-V     20:54:00       20:54:00     6256             13
#
#                          stop_name  stop_lat   stop_lon
# 0        PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254
# 1        PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254
# 2        PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254
# 3        PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254
# 4        PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254
# ...                            ...       ...        ...
# 2581120      RUA JOSE MOREIRA, 593 -3.857633 -38.501887
# 2581121      RUA JOSE MOREIRA, 593 -3.857633 -38.501887
# 2581122      RUA JOSE MOREIRA, 593 -3.857633 -38.501887
# 2581123      RUA JOSE MOREIRA, 593 -3.857633 -38.501887
# 2581124      RUA JOSE MOREIRA, 593 -3.857633 -38.501887
#
# [2581125 rows x 8 columns]

# %%
# Removendo informações desnecessárias do df de dados das viagens
trips_tratado = trips.drop(columns=['service_id', 'trip_headsign', 'trip_short_name', 'direction_id', 'block_id', 'wheelchair_accessible'])

# %%
trips_tratado
# Out:
#        route_id           trip_id    shape_id
# 0            11  D011-T01V01B01-I  shape011-I
# 1            11  D011-T01V02B01-I  shape011-I
# 2            11  D011-T01V03B01-I  shape011-I
# 3            11  D011-T01V04B01-I  shape011-I
# 4            11  D011-T01V05B01-I  shape011-I
# ...         ...               ...         ...
# 83762       920  U920-T06V06B02-I  shape920-I
# 83763       920  U920-T06V06B02-V  shape920-V
# 83764       920  U920-T06V07B02-I  shape920-I
# 83765       920  U920-T06V07B02-V  shape920-V
# 83766       920  U920-T06V08B02-V  shape920-V
#
# [83767 rows x 3 columns]

# %%
# MESCLANDO BASE COM INFORMAÇÕES DAS PARADAS E TEMPOS DE PASSAGENS COM OS DADSO DAS VIAGENS PROGRAMADAS E AS RESPECTIVAS LINHAS
merge_pardas_time_trips = pd.merge(merge_pardas_time, trips_tratado, left_on='trip_id', right_on='trip_id')

# %%
merge_pardas_time_trips
# Out:
#                   trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0        D011-T01V01B01-I     05:13:00       05:13:00     3500              1
# 1        D011-T01V01B01-I     05:15:00       05:15:00     1013              2
# 2        D011-T01V01B01-I     05:16:00       05:16:00     1015              3
# 3        D011-T01V01B01-I     05:17:00       05:17:00     4251              4
# 4        D011-T01V01B01-I     05:18:00       05:18:00      990              5
# ...                   ...          ...            ...      ...            ...
# 2581120  U020-T04V08B01-V     09:42:00       09:42:00     2288              1
# 2581121  U020-T04V08B01-V     09:43:00       09:43:00     2290              2
# 2581122  U020-T04V08B01-V     09:44:00       09:44:00     2006              3
# 2581123  U020-T04V08B01-V     09:47:00       09:47:00     2007              4
# 2581124  U020-T04V08B01-V     09:50:00       09:50:00     1995              5
#
#                           stop_name  stop_lat   stop_lon  route_id    shape_id
# 0         PRAÇA CASTRO CARREIRO, SN -3.722641 -38.530254        11  shape011-I
# 1            AVENIDA IMPERADOR, 270 -3.723690 -38.533477        11  shape011-I
# 2         RUA GUILHERME ROCHA, 1048 -3.724543 -38.535467        11  shape011-I
# 3           RUA GUILHERME ROCHA, SN -3.723803 -38.537737        11  shape011-I
# 4         RUA GUILHERME ROCHA, 1587 -3.723135 -38.539837        11  shape011-I
# ...                             ...       ...        ...       ...         ...
# 2581120  RUA PRO ARMANDO FARIAS, 90 -3.747765 -38.575754        20  shape020-V
# 2581121  RUA PRO ARMANDO FARIAS, 91 -3.747144 -38.573740        20  shape020-V
# 2581122  RUA PRO ARMANDO FARIAS, SN -3.745899 -38.572436        20  shape020-V
# 2581123      RUA AURÉLIO CAMARÁ, SN -3.742524 -38.574766        20  shape020-V
# 2581124     RUA ANDRADE FURTADO, SN -3.739469 -38.572291        20  shape020-V
#
# [2581125 rows x 10 columns]

# %%
''' Por inspeção vimos que possuem horarios de chegada superiores a 24 hs, segue na variavel horario_test'''
# Out:
# ' Por inspeção vimos que possuem horarios de chegada superiores a 24 hs, segue na variavel horario_test'

# %%
# Verificando dados de tempo maiores que 24 (inspessão)
horario_test = merge_pardas_time_trips[merge_pardas_time_trips.arrival_time>='24:00:00' ]

# %%
horario_test
# Out:
#                   trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 18193    D042-T11V07B02-V     24:24:00       24:24:00     6108             62
# 18217    D042-T11V07B02-V     24:00:00       24:00:00      260             32
# 18218    D042-T11V07B02-V     24:01:00       24:01:00     4685             33
# 18220    D042-T11V07B02-V     24:02:00       24:02:00      226             35
# 18221    D042-T11V07B02-V     24:03:00       24:03:00      228             36
# ...                   ...          ...            ...      ...            ...
# 2578550  U214-T02V33B01-V     24:02:00       24:02:00     1457             11
# 2578551  U214-T02V33B01-V     24:03:00       24:03:00     1456             12
# 2578552  U214-T02V33B01-V     24:04:00       24:04:00     1441             13
# 2578553  U214-T02V33B01-V     24:06:00       24:06:00     1436             14
# 2578554  U214-T02V33B01-V     24:07:00       24:07:00     1434             15
#
#                                   stop_name  stop_lat   stop_lon  route_id  \
# 18193    PRAÇA TERMINAL ANTONIO BEZERRA, SN -3.737485 -38.584186        42
# 18217            AVENIDA FRANCISCO SA, 4626 -3.714544 -38.565806        42
# 18218            AVENIDA FRANCISCO SA, 4802 -3.713892 -38.567691        42
# 18220            AVENIDA FRANCISCO SA, 5303 -3.712424 -38.571940        42
# 18221            AVENIDA FRANCISCO SA, 5550 -3.711783 -38.573827        42
# ...                                     ...       ...        ...       ...
# 2578550       RUA PDE PERDIGAO SAMPAIO, 101 -3.734498 -38.595901       214
# 2578551        RUA PDE PERDIGAO SAMPAIO, 05 -3.732612 -38.596769       214
# 2578552          RUA XXV CIDADE OESTE, 2262 -3.731764 -38.598758       214
# 2578553            RUA DO TRABALHADOR, 2726 -3.730530 -38.603201       214
# 2578554          RUA STA MARIA GORETE, 2950 -3.729223 -38.603414       214
#
#            shape_id
# 18193    shape042-V
# 18217    shape042-V
# 18218    shape042-V
# 18220    shape042-V
# 18221    shape042-V
# ...             ...
# 2578550  shape214-V
# 2578551  shape214-V
# 2578552  shape214-V
# 2578553  shape214-V
# 2578554  shape214-V
#
# [6692 rows x 10 columns]

# %%
''' Esses dados são referentes as horarios de 24=00 hs e 25=01hs, foi adotado a substituição de 24 por 00 e 25 por 01 '''
# Out:
# ' Esses dados são referentes as horarios de 24=00 hs e 25=01hs, foi adotado a substituição de 24 por 00 e 25 por 01 '

# %%
# transformanmdo dados de horas para string
merge_pardas_time_trips['arrival_time'] = merge_pardas_time_trips['arrival_time'].astype(str)

# %%
# Função para substituição
def substituir_hora_24(hora):
    return hora.replace("24", "00")
def substituir_hora_25(hora):
    return hora.replace("25", "01")

# %%
# Aplicando função para 24
merge_pardas_time_trips['arrival_time'] = merge_pardas_time_trips['arrival_time'].apply(substituir_hora_24)

# Aplicando função para 25
merge_pardas_time_trips['arrival_time'] = merge_pardas_time_trips['arrival_time'].apply(substituir_hora_25)

# %%
# Transformando coluna de chegada programada do veiculo em tipo data
merge_pardas_time_trips['momento_chegada'] = pd.to_datetime(merge_pardas_time_trips['arrival_time'], format='%H:%M:%S')

# %%
''' 1900-01-01 é uma data generica! '''
# Out:
# ' 1900-01-01 é uma data generica! '

# %%
# Criando coluna de linha (coluna route_id tem essas informações das linhas!)
merge_pardas_time_trips['linha'] = merge_pardas_time_trips['route_id'].astype('int32')

# %%
# Removedno colunas desnecessarias
merge_pardas_time_trips.drop(columns=['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'stop_name', 'route_id', 'shape_id'], inplace=True)

# %%
# Base com linhas e os tempos programados de passagem
merge_pardas_time_trips
# Out:
#          stop_lat   stop_lon     momento_chegada  linha
# 0       -3.722641 -38.530254 1900-01-01 05:13:00     11
# 1       -3.723690 -38.533477 1900-01-01 05:15:00     11
# 2       -3.724543 -38.535467 1900-01-01 05:16:00     11
# 3       -3.723803 -38.537737 1900-01-01 05:17:00     11
# 4       -3.723135 -38.539837 1900-01-01 05:18:00     11
# ...           ...        ...                 ...    ...
# 2581120 -3.747765 -38.575754 1900-01-01 09:42:00     20
# 2581121 -3.747144 -38.573740 1900-01-01 09:43:00     20
# 2581122 -3.745899 -38.572436 1900-01-01 09:44:00     20
# 2581123 -3.742524 -38.574766 1900-01-01 09:47:00     20
# 2581124 -3.739469 -38.572291 1900-01-01 09:50:00     20
#
# [2581125 rows x 4 columns]

# %%
merge_pardas_time_trips.isnull().sum()
# Out:
# stop_lat                0
# stop_lon                0
# momento_chegada    447564
# linha                   0
# dtype: int64

# %%
''' ou seja, existem momentos nulos programados, iremos dropar esses valores!'''
# Out:
# ' ou seja, existem momentos nulos programados, iremos dropar esses valores!'

# %%
merge_pardas_time_trips.dropna(subset=['momento_chegada'], inplace=True)

# %%
# colocando df em ordem pelo momento programado de chegada
merge_pardas_time_trips.sort_values('momento_chegada', inplace=True)

# %%
''' COM BASE CONTENDO HORARIO PROGRAMADO DE CHEGADA PARA CADA LINHA, É POSSIVEL ASSOCIAR O HORARIO PROGRAMADA MAIS PROXIMO DO HORARIO DE VALIDAÇÃO '''
# Out:
# ' COM BASE CONTENDO HORARIO PROGRAMADO DE CHEGADA PARA CADA LINHA, É POSSIVEL ASSOCIAR O HORARIO PROGRAMADA MAIS PROXIMO DO HORARIO DE VALIDAÇÃO '

# %%
# Base dos dados de brt e demais validação sem um veiculo identificado no GPS
dados_brt
# Out:
#               id  linha           nome_linha  prefixo_carro      tipo_cartao  \
# 0        7165982    841           HGF/PAPICU           2131  Vale transporte
# 1        7455408    841           HGF/PAPICU           2131  Vale transporte
# 2        7360199    841           HGF/PAPICU           2131  Vale transporte
# 3        7360332    841           HGF/PAPICU           2131  Vale transporte
# 4        7119083    841           HGF/PAPICU           2131  Vale transporte
# ...          ...    ...                  ...            ...              ...
# 2179944        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179945        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179946        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179947        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179948        0    728  JOSE WALTER/ CENTRO          67252          Inteira
#
#                     momento
# 0       2018-11-01 16:22:49
# 1       2018-11-01 16:24:21
# 2       2018-11-01 16:24:31
# 3       2018-11-01 23:22:33
# 4       2018-11-01 22:56:38
# ...                     ...
# 2179944 2018-11-30 07:28:01
# 2179945 2018-11-30 07:34:25
# 2179946 2018-11-30 07:40:20
# 2179947 2018-11-30 07:41:30
# 2179948 2018-11-30 07:46:19
#
# [2179949 rows x 6 columns]

# %%
# Criando coluna com dados de hoario, minuto e segundos de validação 
dados_brt['momento_validacao_curto'] = dados_brt['momento'].dt.strftime('%H:%M:%S')
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\497672285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_brt['momento_validacao_curto'] = dados_brt['momento'].dt.strftime('%H:%M:%S')

# %%
# Transformando coluna de hoario de validação em tipo data
dados_brt['momento_validacao_curto'] = pd.to_datetime(dados_brt['momento_validacao_curto'], format='%H:%M:%S')
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\1223969118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_brt['momento_validacao_curto'] = pd.to_datetime(dados_brt['momento_validacao_curto'], format='%H:%M:%S')

# %%
dados_brt # NOVAMENTE 1900-01-01 é uma data generica!
# Out:
#               id  linha           nome_linha  prefixo_carro      tipo_cartao  \
# 0        7165982    841           HGF/PAPICU           2131  Vale transporte
# 1        7455408    841           HGF/PAPICU           2131  Vale transporte
# 2        7360199    841           HGF/PAPICU           2131  Vale transporte
# 3        7360332    841           HGF/PAPICU           2131  Vale transporte
# 4        7119083    841           HGF/PAPICU           2131  Vale transporte
# ...          ...    ...                  ...            ...              ...
# 2179944        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179945        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179946        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179947        0    728  JOSE WALTER/ CENTRO          67252          Inteira
# 2179948        0    728  JOSE WALTER/ CENTRO          67252          Inteira
#
#                     momento momento_validacao_curto
# 0       2018-11-01 16:22:49     1900-01-01 16:22:49
# 1       2018-11-01 16:24:21     1900-01-01 16:24:21
# 2       2018-11-01 16:24:31     1900-01-01 16:24:31
# 3       2018-11-01 23:22:33     1900-01-01 23:22:33
# 4       2018-11-01 22:56:38     1900-01-01 22:56:38
# ...                     ...                     ...
# 2179944 2018-11-30 07:28:01     1900-01-01 07:28:01
# 2179945 2018-11-30 07:34:25     1900-01-01 07:34:25
# 2179946 2018-11-30 07:40:20     1900-01-01 07:40:20
# 2179947 2018-11-30 07:41:30     1900-01-01 07:41:30
# 2179948 2018-11-30 07:46:19     1900-01-01 07:46:19
#
# [2179949 rows x 7 columns]

# %%
# colocando df em ordem pelo momento de validação 
dados_brt.sort_values('momento_validacao_curto', inplace=True)
# Out:
# C:\Users\Bolsista\AppData\Local\Temp\ipykernel_1400\3277456000.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_brt.sort_values('momento_validacao_curto', inplace=True)

# %%
dados_brt.isnull().sum()
# Out:
# id                         0
# linha                      0
# nome_linha                 0
# prefixo_carro              0
# tipo_cartao                0
# momento                    0
# momento_validacao_curto    0
# dtype: int64

# %%
# REALIZANDO OPERAÇÃO DE MESCLAGEM PARA LOCALIZAR PELO TEMPO MAIS PROXIMO DE PASSAGEM COM O DE VALIDAÇÃO 
dados_brt_geo_ = pd.merge_asof(dados_brt, merge_pardas_time_trips, left_on='momento_validacao_curto', right_on='momento_chegada', by='linha', direction ='nearest')

# %%
# Dropando colunas denecessárias
dados_brt_geo_.drop(columns=['momento_validacao_curto', 'momento_chegada'], inplace=True)

# %%
# Criando colun id_veiculo e cod_veiculo para mesclagem das bases
dados_brt_geo_['id_veiculo'] = 'validacao_brt_outros'
dados_brt_geo_['cod_veiculo'] = 'validacao_brt_outros'

# %%
dados_brt_geo_.rename(columns={'stop_lat': 'latitude', 'stop_lon': 'longitude'}, inplace=True)

# %%
# Reordenando colunas 
dados_brt_geo = dados_brt_geo_[['id', 'linha', 'nome_linha', 'prefixo_carro', 'tipo_cartao', 'momento', 'id_veiculo', 'cod_veiculo', 'latitude', 'longitude']]

# %%
del dados_brt_geo_

# %%
# BASE LOCALIZADA COM VALIDAÇÕES EM ESTAÇÕES DE BRT E EM CASOS QUE NÃO SE TEM UM VEICULO CORRESPONDENTE NO GPS
dados_brt_geo
# Out:
#               id  linha            nome_linha  prefixo_carro      tipo_cartao  \
# 0        6954372    762  Caca e Pesca/Centro/          67926        Estudante
# 1        7497973    629  Cj Palmeiras/Perimet          35136  Vale transporte
# 2        2673835    629  Cj Palmeiras/Perimet          35136        Estudante
# 3              0    762  Caca e Pesca/Centro/          67357          Inteira
# 4        7217445    762  Caca e Pesca/Centro/          67357  Vale transporte
# ...          ...    ...                   ...            ...              ...
# 2179944        0    762  Caca e Pesca/Centro/          67926          Inteira
# 2179945  2361605    762  Caca e Pesca/Centro/          67926  Vale transporte
# 2179946        0    762  Caca e Pesca/Centro/          67357          Inteira
# 2179947  5372257    629  Cj Palmeiras/Perimet          35136  Vale transporte
# 2179948        0    629  Cj Palmeiras/Perimet          35136          Inteira
#
#                     momento            id_veiculo           cod_veiculo  \
# 0       2018-11-23 00:00:05  validacao_brt_outros  validacao_brt_outros
# 1       2018-11-08 00:00:17  validacao_brt_outros  validacao_brt_outros
# 2       2018-11-09 00:00:27  validacao_brt_outros  validacao_brt_outros
# 3       2018-12-01 00:00:40  validacao_brt_outros  validacao_brt_outros
# 4       2018-12-01 00:00:44  validacao_brt_outros  validacao_brt_outros
# ...                     ...                   ...                   ...
# 2179944 2018-11-23 23:59:41  validacao_brt_outros  validacao_brt_outros
# 2179945 2018-11-23 23:59:46  validacao_brt_outros  validacao_brt_outros
# 2179946 2018-11-30 23:59:48  validacao_brt_outros  validacao_brt_outros
# 2179947 2018-11-23 23:59:49  validacao_brt_outros  validacao_brt_outros
# 2179948 2018-11-28 23:59:52  validacao_brt_outros  validacao_brt_outros
#
#          latitude  longitude
# 0       -3.750196 -38.448727
# 1       -3.835546 -38.521672
# 2       -3.835546 -38.521672
# 3       -3.754544 -38.446605
# 4       -3.754544 -38.446605
# ...           ...        ...
# 2179944 -3.766244 -38.440909
# 2179945 -3.766244 -38.440909
# 2179946 -3.766244 -38.440909
# 2179947 -3.833903 -38.521620
# 2179948 -3.833903 -38.521620
#
# [2179949 rows x 10 columns]

# %% [markdown]
# ## 3.4 JUNÇÃO DAS VALIDAÇÕES LOCALIZADAS EM UMA UNICA BASE
# ''' COM DADOS DE VALIDAÇÕES LOCALIZADOS EM TERMINAIS, EM LINHAS DE BRT´s E EM VALIDAÇÕES EM LINHAS DE ONIBUS CONVENCIONAIS É POSSIVEL JUNTAR ESSAS EM UMA UNICA BASE'''

# %%
# Concatenando base em um unico df
bilhetagem_localizada = pd.concat([mes_d1_GPS, dados_terminais_geo, dados_brt_geo])

# %%
# Base localizada
bilhetagem_localizada
# Out:
#               id  linha            nome_linha  prefixo_carro      tipo_cartao  \
# 0        6495289     95  Corujao/Cj Pref. Jos          26407       Gratuidade
# 1              0     54  Corujao/Praia do Fut          30426          Inteira
# 2        6730926     57  Corujao/Jardim Irace          35120  Vale transporte
# 3        4841184     57  Corujao/Jardim Irace          35120  Vale transporte
# 4        7317420     90  Corujao/Montese               12219  Vale transporte
# ...          ...    ...                   ...            ...              ...
# 2179944        0    762  Caca e Pesca/Centro/          67926          Inteira
# 2179945  2361605    762  Caca e Pesca/Centro/          67926  Vale transporte
# 2179946        0    762  Caca e Pesca/Centro/          67357          Inteira
# 2179947  5372257    629  Cj Palmeiras/Perimet          35136  Vale transporte
# 2179948        0    629  Cj Palmeiras/Perimet          35136          Inteira
#
#                     momento            id_veiculo           cod_veiculo  \
# 0       2018-11-01 00:01:21                 32409                 26407
# 1       2018-11-01 00:11:05                 33276                 30426
# 2       2018-11-01 00:12:16                 33801                 35120
# 3       2018-11-01 00:12:30                 33801                 35120
# 4       2018-11-01 00:13:58                 33637                 12219
# ...                     ...                   ...                   ...
# 2179944 2018-11-23 23:59:41  validacao_brt_outros  validacao_brt_outros
# 2179945 2018-11-23 23:59:46  validacao_brt_outros  validacao_brt_outros
# 2179946 2018-11-30 23:59:48  validacao_brt_outros  validacao_brt_outros
# 2179947 2018-11-23 23:59:49  validacao_brt_outros  validacao_brt_outros
# 2179948 2018-11-28 23:59:52  validacao_brt_outros  validacao_brt_outros
#
#          latitude  longitude
# 0       -3.838164 -38.558586
# 1       -3.740973 -38.539021
# 2       -3.722791 -38.530235
# 3       -3.722791 -38.530235
# 4       -3.780263 -38.570004
# ...           ...        ...
# 2179944 -3.766244 -38.440909
# 2179945 -3.766244 -38.440909
# 2179946 -3.766244 -38.440909
# 2179947 -3.833903 -38.521620
# 2179948 -3.833903 -38.521620
#
# [24891023 rows x 10 columns]

# %%
# Exportando base localizada para csv
# bilhetagem_localizada.to_csv('bilhetagem_localizada_11_2018')

# %% [markdown]
# ### 3.4.1 Filtrando veiculos em trecho com estações de BRT

# %%
# Na base dos veiculos em fora de terminais e que possuem um veiculo associado do GPS
validacoes_base_mes_d1_GPS = mes_d1_GPS[(mes_d1_GPS.latitude>=-3.736011)
    & (mes_d1_GPS.longitude>=-38.566622) & (mes_d1_GPS.longitude<=-38.545669) 
                                & (mes_d1_GPS.latitude<=-3.731734)]

# %%
# 
validacoes_base_mes_d1_GPS['linha'].unique()
# Out:
# array([363, 215,  24,  26, 214,  28,  86, 217, 216,  88,  42, 220, 120,
#        108,  76,  74, 222,  52, 225,  71,  92,  79, 226, 200,  51, 244,
#         32, 855,  60, 389, 111,  31,  81,  50, 711, 627,  98, 286, 341,
#         99,  34,  35,  37, 302,  39,  12, 130,  75, 602,  97,  16,  45,
#        114, 320, 841, 820, 650, 303,  66,  44, 343, 205, 906,  41,  72,
#        350,  56,  77, 122,  82, 206, 102,  69, 504,  11, 340, 364,  61,
#         80, 372, 622, 616,   1,  70, 330,  15, 174, 383])

# %%
validacoes_base_mes_d1_GPS[validacoes_base_mes_d1_GPS.linha==855]
# Out:
#                id  linha            nome_linha  prefixo_carro  \
# 271033          0    855  Bezerra de Menezes/           30511
# 271209    7464783    855  Bezerra de Menezes/           30511
# 271354          0    855  Bezerra de Menezes/           30511
# 271501    2083501    855  Bezerra de Menezes/           30511
# 272254    6506979    855  Bezerra de Menezes/           30511
# ...           ...    ...                   ...            ...
# 21599165  7459357    855  Bezerra de Menezes/           20593
# 21599288        0    855  Bezerra de Menezes/           20593
# 21599292        0    855  Bezerra de Menezes/           20593
# 21599338  7301897    855  Bezerra de Menezes/           20593
# 21599377  7281462    855  Bezerra de Menezes/           30521
#
#               tipo_cartao             momento  id_veiculo  cod_veiculo  \
# 271033            Inteira 2018-11-01 08:58:05       33289        30511
# 271209    Vale transporte 2018-11-01 08:58:22       33289        30511
# 271354            Inteira 2018-11-01 08:58:36       33289        30511
# 271501         Gratuidade 2018-11-01 08:58:48       33289        30511
# 272254          Estudante 2018-11-01 08:59:47       33289        30511
# ...                   ...                 ...         ...          ...
# 21599165  Vale transporte 2018-11-30 23:24:01       33187        20593
# 21599288          Inteira 2018-11-30 23:25:50       33187        20593
# 21599292          Inteira 2018-11-30 23:25:54       33187        20593
# 21599338  Vale transporte 2018-11-30 23:27:02       33187        20593
# 21599377  Vale transporte 2018-11-30 23:27:47       33307        30521
#
#           latitude  longitude
# 271033   -3.731995 -38.546726
# 271209   -3.731995 -38.546726
# 271354   -3.732145 -38.547394
# 271501   -3.732145 -38.547394
# 272254   -3.732979 -38.551594
# ...            ...        ...
# 21599165 -3.733346 -38.553333
# 21599288 -3.734233 -38.557800
# 21599292 -3.734233 -38.557800
# 21599338 -3.734828 -38.560841
# 21599377 -3.732603 -38.549587
#
# [14763 rows x 10 columns]

# %%
validacoes_base_mes_d1_GPS[validacoes_base_mes_d1_GPS.linha==86]
# Out:
#                id  linha          nome_linha  prefixo_carro      tipo_cartao  \
# 187404          0     86  Bezerra / S.Dumont          30315          Inteira
# 187586    7319892     86  Bezerra / S.Dumont          30315  Vale transporte
# 190313    7104004     86  Bezerra / S.Dumont          30315  Vale transporte
# 228720          0     86  Bezerra / S.Dumont          30121          Inteira
# 229191    7319711     86  Bezerra / S.Dumont          30121  Vale transporte
# ...           ...    ...                 ...            ...              ...
# 21598691  3920426     86  Bezerra / S.Dumont          30202        Estudante
# 21598722  7232367     86  Bezerra / S.Dumont          30202  Vale transporte
# 21598743  7207583     86  Bezerra / S.Dumont          30202  Vale transporte
# 21598775  5307942     86  Bezerra / S.Dumont          30202        Estudante
# 21600365        0     86  Bezerra / S.Dumont          30311          Inteira
#
#                      momento  id_veiculo  cod_veiculo  latitude  longitude
# 187404   2018-11-01 07:29:06       33183        30315 -3.735648 -38.564373
# 187586   2018-11-01 07:29:13       33183        30315 -3.735648 -38.564373
# 190313   2018-11-01 07:31:13       33183        30315 -3.734476 -38.558712
# 228720   2018-11-01 08:05:34       32956        30121 -3.735615 -38.564362
# 229191   2018-11-01 08:06:04       32956        30121 -3.735405 -38.563084
# ...                      ...         ...          ...       ...        ...
# 21598691 2018-11-30 23:17:53       33044        30202 -3.735446 -38.563835
# 21598722 2018-11-30 23:18:08       33044        30202 -3.735443 -38.563835
# 21598743 2018-11-30 23:18:23       33044        30202 -3.735443 -38.563835
# 21598775 2018-11-30 23:18:49       33044        30202 -3.735693 -38.565025
# 21600365 2018-11-30 23:50:38       33166        30311 -3.732073 -38.547318
#
# [11549 rows x 10 columns]

# %%
validacoes_base_mes_d1_GPS[validacoes_base_mes_d1_GPS.prefixo_carro==30530]
# Out:
# Empty DataFrame
# Columns: [id, linha, nome_linha, prefixo_carro, tipo_cartao, momento, id_veiculo, cod_veiculo, latitude, longitude]
# Index: []

# %%
# Filtrando linhas especifica
linha_especifica = validacoes_base_mes_d1_GPS[validacoes_base_mes_d1_GPS.nome_linha== 'Antonio Bezerra/Papi']

# %%
tempo_especifico = linha_especifica[(linha_especifica.momento>= '2018-11-01 08:33:23')
    & (linha_especifica.momento<= '2018-11-01 08:36:02')]

# %%
# df com validações em uma mesma linha, mesmo veiculo e momentos seguindos
# tempo_especifico

# %%
validacoes_base_mes_d1_GPS['linha'].value_counts().sum()
# Out:
# 145954

# %%
# Na base dos veiculos em fora de terminais e que não possuem um veciulo associado no GPS 
validacoes_base_dados_brt_geo = dados_brt_geo[(dados_brt_geo.latitude>=-3.736011)
    & (dados_brt_geo.longitude>=-38.566622) & (dados_brt_geo.longitude<=-38.545669) 
                                & (dados_brt_geo.latitude<=-3.731734)]

# %%
validacoes_base_dados_brt_geo['nome_linha'].unique() # Nenhuma linha com nome estação!
# Out:
# array(['BARRA DO CEARA/ANTON', 'Bezerra / S.Dumont', 'VILA VELHA/ CENTRO',
#        'CONJ. ALVORADA/ NORT', 'SANTOS DUMONT/ PERIM',
#        'Bezerra de Menezes/ '], dtype=object)

# %%
validacoes_base_dados_brt_geo['linha'].unique() # Nenhuma linha com nome estação!
# Out:
# array([706,  86, 757, 755, 713, 855])

# %%
validacoes_base_dados_brt_geo[validacoes_base_dados_brt_geo.linha==855]
# Out:
#               id  linha            nome_linha  prefixo_carro      tipo_cartao  \
# 896105         0    855  Bezerra de Menezes/           30530          Inteira
# 953888   7011556    855  Bezerra de Menezes/           30530  Vale transporte
# 1285378        0    855  Bezerra de Menezes/           30530          Inteira
# 1286014        0    855  Bezerra de Menezes/           30530          Inteira
# 1555626  4998085    855  Bezerra de Menezes/           30530  Vale transporte
# 1555968   111650    855  Bezerra de Menezes/           30530        Estudante
# 1698400  6842252    855  Bezerra de Menezes/           30530  Vale transporte
# 1703130  7007659    855  Bezerra de Menezes/           30530  Vale transporte
# 1788388  7434660    855  Bezerra de Menezes/           30530  Vale transporte
# 1857336  6844697    855  Bezerra de Menezes/           30530  Vale transporte
# 1857753  4937605    855  Bezerra de Menezes/           30530  Vale transporte
# 1916167  7010385    855  Bezerra de Menezes/           30530  Vale transporte
# 1922544        0    855  Bezerra de Menezes/           30530          Inteira
# 1996821        0    855  Bezerra de Menezes/           30530          Inteira
# 2023192  2875558    855  Bezerra de Menezes/           30530        Estudante
# 2023310  6009215    855  Bezerra de Menezes/           30530  Vale transporte
# 2023450  6009215    855  Bezerra de Menezes/           30530  Vale transporte
# 2023711  2495041    855  Bezerra de Menezes/           30530        Estudante
# 2095559  7413999    855  Bezerra de Menezes/           30530  Vale transporte
# 2098979  7190781    855  Bezerra de Menezes/           30530  Vale transporte
# 2111234        0    855  Bezerra de Menezes/           30530          Inteira
#
#                     momento            id_veiculo           cod_veiculo  \
# 896105  2018-11-25 11:26:18  validacao_brt_outros  validacao_brt_outros
# 953888  2018-11-25 11:54:16  validacao_brt_outros  validacao_brt_outros
# 1285378 2018-11-25 14:26:08  validacao_brt_outros  validacao_brt_outros
# 1286014 2018-11-25 14:26:28  validacao_brt_outros  validacao_brt_outros
# 1555626 2018-11-25 16:30:00  validacao_brt_outros  validacao_brt_outros
# 1555968 2018-11-25 16:30:07  validacao_brt_outros  validacao_brt_outros
# 1698400 2018-11-25 17:17:54  validacao_brt_outros  validacao_brt_outros
# 1703130 2018-11-25 17:19:27  validacao_brt_outros  validacao_brt_outros
# 1788388 2018-11-25 17:47:29  validacao_brt_outros  validacao_brt_outros
# 1857336 2018-11-25 18:10:45  validacao_brt_outros  validacao_brt_outros
# 1857753 2018-11-25 18:10:53  validacao_brt_outros  validacao_brt_outros
# 1916167 2018-11-25 18:31:31  validacao_brt_outros  validacao_brt_outros
# 1922544 2018-11-25 18:34:01  validacao_brt_outros  validacao_brt_outros
# 1996821 2018-11-25 19:08:26  validacao_brt_outros  validacao_brt_outros
# 2023192 2018-11-25 19:22:38  validacao_brt_outros  validacao_brt_outros
# 2023310 2018-11-25 19:22:42  validacao_brt_outros  validacao_brt_outros
# 2023450 2018-11-25 19:22:47  validacao_brt_outros  validacao_brt_outros
# 2023711 2018-11-25 19:22:57  validacao_brt_outros  validacao_brt_outros
# 2095559 2018-11-25 20:22:19  validacao_brt_outros  validacao_brt_outros
# 2098979 2018-11-25 20:26:02  validacao_brt_outros  validacao_brt_outros
# 2111234 2018-11-25 20:41:08  validacao_brt_outros  validacao_brt_outros
#
#          latitude  longitude
# 896105  -3.733243 -38.552973
# 953888  -3.732564 -38.549467
# 1285378 -3.733666 -38.554837
# 1286014 -3.733666 -38.554837
# 1555626 -3.734092 -38.556989
# 1555968 -3.734092 -38.556989
# 1698400 -3.731971 -38.546775
# 1703130 -3.732564 -38.549467
# 1788388 -3.731971 -38.546775
# 1857336 -3.733666 -38.554837
# 1857753 -3.733666 -38.554837
# 1916167 -3.732564 -38.549467
# 1922544 -3.734564 -38.559192
# 1996821 -3.735704 -38.564702
# 2023192 -3.731971 -38.546775
# 2023310 -3.731971 -38.546775
# 2023450 -3.731971 -38.546775
# 2023711 -3.731971 -38.546775
# 2095559 -3.735704 -38.564702
# 2098979 -3.733666 -38.554837
# 2111234 -3.733243 -38.552973

# %%
validacoes_base_dados_brt_geo[validacoes_base_dados_brt_geo.linha==86]
# Out:
#               id  linha          nome_linha  prefixo_carro      tipo_cartao  \
# 10584    4272848     86  Bezerra / S.Dumont          35510       Gratuidade
# 22918    7372895     86  Bezerra / S.Dumont          35510  Vale transporte
# 23266    7542363     86  Bezerra / S.Dumont          35510  Vale transporte
# 28861    7319876     86  Bezerra / S.Dumont          35510  Vale transporte
# 29075    5017935     86  Bezerra / S.Dumont          35510  Vale transporte
# ...          ...    ...                 ...            ...              ...
# 2068972  2892972     86  Bezerra / S.Dumont          35510        Estudante
# 2071999        0     86  Bezerra / S.Dumont          35510          Inteira
# 2075045  6359673     86  Bezerra / S.Dumont          35510  Vale transporte
# 2075213        0     86  Bezerra / S.Dumont          35510          Inteira
# 2075302        0     86  Bezerra / S.Dumont          35510          Inteira
#
#                     momento            id_veiculo           cod_veiculo  \
# 10584   2018-11-10 05:02:15  validacao_brt_outros  validacao_brt_outros
# 22918   2018-11-24 05:19:34  validacao_brt_outros  validacao_brt_outros
# 23266   2018-11-17 05:19:55  validacao_brt_outros  validacao_brt_outros
# 28861   2018-11-17 05:24:39  validacao_brt_outros  validacao_brt_outros
# 29075   2018-11-17 05:24:50  validacao_brt_outros  validacao_brt_outros
# ...                     ...                   ...                   ...
# 2068972 2018-11-03 19:56:57  validacao_brt_outros  validacao_brt_outros
# 2071999 2018-11-17 19:59:48  validacao_brt_outros  validacao_brt_outros
# 2075045 2018-11-24 20:02:34  validacao_brt_outros  validacao_brt_outros
# 2075213 2018-11-24 20:02:44  validacao_brt_outros  validacao_brt_outros
# 2075302 2018-11-24 20:02:49  validacao_brt_outros  validacao_brt_outros
#
#          latitude  longitude
# 10584   -3.733666 -38.554837
# 22918   -3.732564 -38.549467
# 23266   -3.732564 -38.549467
# 28861   -3.734564 -38.559192
# 29075   -3.734564 -38.559192
# ...           ...        ...
# 2068972 -3.735207 -38.562425
# 2071999 -3.733243 -38.552973
# 2075045 -3.735207 -38.562425
# 2075213 -3.735207 -38.562425
# 2075302 -3.735207 -38.562425
#
# [220 rows x 10 columns]

# %%
validacoes_base_dados_brt_geo['linha'].value_counts().sum()
# Out:
# 38874

# %%
''' OU SEJA, NESSE TRECHO EXISTEM 10 ESTAÇÕES DE BRT E NASA DUAS BASES SOMENTE TEM UMA NA PRIMERIA QUE TEM NOME ESTAÇÃO! E NA BASE QUE NÃO POSSUEM VEICULOS ASSOCIADOS, FORAM DE VALIDAÇÕES EM SOMENTE ALGUAMS LINHAS, E AS DEMAIS VALIDAÇÕES NOS CASOS QUE POSSUEM UM VEICULO CORRESPONDENTE NO GPS, EXISTEM TAMBEM LINHAS QUE PASSAM NESSAS ESTAÇÕES E ELAS POSSUEM NOMES PROPRIOS E NÃO O NOME DA ESTAÇÃO!'''
# Out:
# ' OU SEJA, NESSE TRECHO EXISTEM 10 ESTAÇÕES DE BRT E NASA DUAS BASES SOMENTE TEM UMA NA PRIMERIA QUE TEM NOME ESTAÇÃO! E NA BASE QUE NÃO POSSUEM VEICULOS ASSOCIADOS, FORAM DE VALIDAÇÕES EM SOMENTE ALGUAMS LINHAS, E AS DEMAIS VALIDAÇÕES NOS CASOS QUE POSSUEM UM VEICULO CORRESPONDENTE NO GPS, EXISTEM TAMBEM LINHAS QUE PASSAM NESSAS ESTAÇÕES E ELAS POSSUEM NOMES PROPRIOS E NÃO O NOME DA ESTAÇÃO!'

# %% [markdown]
# # 4.0 Plotagem da bilhetagem georreferenciada

# %%
# INSTALANDO A BIBLIOTECA GEOPANDAS COM CONDA
# !conda install geopandas -y

# instalando com pip
# !pip install-q geopandas

# %%
# mostrar a versão da biblioteca 
# !pip list geopandas

# %%
# instalando a biblioteca matplotlib com conda
# !conda install matplotlib -y

# instalando com pip
# !pip install -q matplotlib

# %%
# mostrar a versão da biblioteca 
# !pip list matplotlib

# %%
# importando as bibliotecas
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 4.2 Leitura de dados espaciais

# %%
# Ler os dados com geopandas
ceara_muni = gpd.read_file('CE_Municipios_2022.shp')

# %% [markdown]
# ### 4.2.1 Visualização dos dados

# %%
# Visualização
# ceara_muni.plot(figsize=(16,14), facecolor='white', edgecolor='black') 
#plt.show()

# %% [markdown]
# ### 4.2.2 Filtro somente da capital

# %%
# Salvando somente a capital 'Fortaleza'
fortal = ceara_muni[ceara_muni.NM_MUN=='Fortaleza']
fortal_p = fortal.iloc[0].geometry

# %%
# Mostrar capital 
fortal_p

# %%
# Salvar o geodataframe com formato geojson
filename =  'fortal.json'
fortal.to_file(filename, driver='GeoJSON')

# %%
fortall = gpd.read_file(filename, driver='GeoJSON')

# %%
fortall

# %% [markdown]
# ### 4.2.3 Modelo de dados espaciais e criação de coluna geometrica

# %%
# Instalando biblioteca shapely com pip
# !pip install -q shapely
# Mostrar versão da biblioteca 
# !pip list shapely

# %%
# importando os objetos geométricos da biblioteca shapely
from shapely.geometry import Point, LineString, Polygon

# %%
# Criando coluna geometerica no df (mes_d1_GPS)
# mes_d1_GPS['geometry'] = None 
# for index, row in mes_d1_GPS.iterrows():
    #mes_d1_GPS.loc[index, 'geometry'] = Point(row.latitude, row.longitude)

# %%
# mes_d1_GPS

# %%
# Criando coluna geometerica no df (mes_d1_GPS)
# mes_d1_GPS['geometry'] = mes_d1_GPS.apply(lambda x: Point((float(x.longitude), float(x.latitude))), axis=1)

# %%
# tipos de dados 
# type(mes_d1_GPS)

# %%
# Criando um GeoDataFrame 
# mes_d1_GPS_geodat_ = gpd.GeoDataFrame(mes_d1_GPS, geometry='geometry')

# %%
# mostar dados
# mes_d1_GPS_geodat_= mes_d1_GPS

# %%
# Salvar o geodataframe com formato geojson
# filename2 =  'mes_d1_GPS_geodat_.json'
# mes_d1_GPS_geodat_.to_file(filename2, driver='GeoJSON')

# %%
# mes_d1_GPS_geodat = gpd.read_file(filename2, driver='GeoJSON')

# %%
# plotando dados (visualização)
# mes_d1_GPS_geodat.plot(figsize=(8,8), facecolor='white', edgecolor='black')

# %%
# type(mes_d1_GPS_geodat)

# %% [markdown]
# ### 4.2.4 Operação de interseção entre geometrias

# %%
# Mostrar os dados simultaneamente
# fig, ax = plt.subplots(figsize=(15,15))

# mes_d1_GPS_geodat.plot(ax=ax)
# fortall.plot(ax=ax, facecolor='None', edgecolor='black')

# %%
# VERIFICAMOS QUE EXISTEM DADOS GEORREFERENCIADOS FORA DA MALHA DA CIDADE, PODENDO SER NA SUA MAIORIA REGISTRO DOS VEICULOS
# QUANDO SE DESLOCARAM PARA OUTRAS ZONAS, OU ATÉ MESMO ERROS DO APARELHO DE GPS, COMO MOSTRA NA FIGURA ACIMA UM REGISTRO 
# PRATICAMENTE NO MAR.

# %%
# Realizar operação de interseção entre geometrias
# mes_geo_fortal = mes_d1_GPS_geodat[mes_d1_GPS_geodat.intersects(fortal_p)]

# %%
# mes_geo_fortal.info()

# %%
# NOTAMOS QUE DOS 891038 DADOS DE VALIDAÇÕES APENAS 825386 foram localizadas dentro da malha da cidade, seguimos com estas!

# %%
# Mostrar os dados simultaneamente após interseção
# fig, ax = plt.subplots(figsize=(10,10))

# mes_geo_fortal.plot(ax=ax)
# fortall.plot(ax=ax, facecolor='None', edgecolor='black')

# %%
# Salvando os dados georreferenciados em fortaleza 
# filename3 = 'mes_geo_fortal.json'

# mes_geo_fortal.to_file(filename3, driver='GeoJSON')

# %% [markdown]
# ### 4.2.5 Mostrando dados no mapa de agrupamento (clusters)

# %%
# Instalando biblioteca folium com pip!
# !pip install -q folium

# %%
# importando biblioteca folium e pluging
import folium 
from folium.plugins import FastMarkerCluster

# %%
# Criar mapa de agrupamentos (clusters)
# media_long = mes_geo_fortal['longitude'].mean()
# media_lat = mes_geo_fortal['latitude'].mean()

# mapa = folium.Map(location=[media_lat, media_long])

# %%
# Transformando dados em uma feat geojson
# mc = FastMarkerCluster(mes_geo_fortal[['latitude', 'longitude']])

# %%
# Poligonal da cidade no mapa
limites = folium.features.GeoJson(fortall, style_function=lambda feature:{'color': 'black', 'weight': 2, 'fillOpacity':0.0})

# %%
# Adicionando dados no mapa
# mapa.add_child(mc)
# mapa.add_child(limites)

# %%
# Salvar o nosso mapa em um arquivo html
# mapa.save('validações_georreferenciadas.html')

# %% [markdown]
# ### 4.2.6 Mostrando dados no mapa de calor (Heatmap)

# %%
# Importando a plugin HeatMap
from folium.plugins import HeatMap

# %%
# Criando mapa II

# mapa_2 = folium.Map(location=[media_lat, media_long]) 

# Criando heat_map
# heat_map = HeatMap(mes_geo_fortal[['latitude', 'longitude']])

# %%
# Adicionando no map
# mapa_2.add_child(heat_map)
# mapa_2.add_child(limites)

# %%
# Salvar o nosso mapa em um arquivo html
# mapa_2.save('validações_georreferenciadas_Heatmap_calor.html')

# %% [markdown]
# # ------------------------------------------------------------------------
